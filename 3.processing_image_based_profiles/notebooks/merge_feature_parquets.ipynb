# %%
import pathlib
import pprint
import sqlite3

import duckdb
import pandas as pd

# %%
well_fov = "C4-2"

result_path = pathlib.Path(f"../../2.cellprofiling/results/{well_fov}/").resolve(
    strict=True
)
database_path = pathlib.Path("../results/").resolve()
database_path.mkdir(parents=True, exist_ok=True)
# create the sqlite database
sqlite_path = database_path / f"{well_fov}.sqlite"


# get a list of all parquets in the directory
parquet_files = list(result_path.glob("*.parquet"))
parquet_files.sort()

# %%
feature_types_dict = {
    "Organoid": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Cell": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Nuclei": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Cytoplasm": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
}
for file in parquet_files:
    for compartment in feature_types_dict.keys():
        for feature_type in feature_types_dict[compartment].keys():
            if compartment in file.name and feature_type in file.name:
                feature_types_dict[compartment][feature_type].append(file)
pprint.pprint(feature_types_dict)
# Out:
# {'Cell': {'AreaSize_Shape': [],
#           'Colocalization': [],
#           'Granularity': [],
#           'Intensity': [],
#           'Neighbor': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Neighbors_Cell_DNA_features.parquet')],
#           'Texture': []},
#  'Cytoplasm': {'AreaSize_Shape': [],
#                'Colocalization': [],
#                'Granularity': [],
#                'Intensity': [],
#                'Neighbor': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Neighbors_Cytoplasm_DNA_features.parquet')],
#                'Texture': []},
#  'Nuclei': {'AreaSize_Shape': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/AreaSize_Shape_Nuclei_DNA_features.parquet')],
#             'Colocalization': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Colocalization_Nuclei_DNA.AGP_features.parquet')],
#             'Granularity': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Granularity_Nuclei_DNA_features.parquet')],
#             'Intensity': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Intensity_Nuclei_DNA_features.parquet')],
#             'Neighbor': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Neighbors_Nuclei_DNA_features.parquet')],
#             'Texture': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Texture_Nuclei_DNA_features.parquet')]},
#  'Organoid': {'AreaSize_Shape': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/AreaSize_Shape_Organoid_DNA_features.parquet')],
#               'Colocalization': [],
#               'Granularity': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Granularity_Organoid_DNA_features.parquet')],
#               'Intensity': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Intensity_Organoid_DNA_features.parquet')],
#               'Neighbor': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Neighbors_Organoid_DNA_features.parquet')],
#               'Texture': [PosixPath('/home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/results/C4-2/Texture_Organoid_DNA_features.parquet')]}}

# %%
# create a record for each compartment
merged_df_dict = {
    "Organoid": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Cell": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Nuclei": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
    "Cytoplasm": {
        "AreaSize_Shape": [],
        "Colocalization": [],
        "Intensity": [],
        "Granularity": [],
        "Neighbor": [],
        "Texture": [],
    },
}

for compartment in feature_types_dict.keys():
    for feature_type in feature_types_dict[compartment].keys():
        if len(feature_types_dict[compartment][feature_type]) > 0:
            for file in feature_types_dict[compartment][feature_type]:
                # check if the file exists
                if not file.exists():
                    print(f"File {file} does not exist")
                    continue
                # check if the file is a parquet file
                if not file.name.endswith(".parquet"):
                    print(f"File {file} is not a parquet file")
                    continue
                # read the parquet files
                try:
                    df = duckdb.read_parquet(str(file)).to_df()
                except Exception as e:
                    print(
                        f"Error reading {feature_types_dict[compartment][feature_type]}: {e}"
                    )
                    df = pd.DataFrame()

                # add the dataframe to the dictionary
                merged_df_dict[compartment][feature_type].append(df)
        else:
            print(
                f"No files found for {compartment} {feature_type}. Please check the directory."
            )
            merged_df_dict[compartment][feature_type].append(pd.DataFrame())
        # merge the dataframes
        merged_df_dict[compartment][feature_type] = pd.concat(
            merged_df_dict[compartment][feature_type], ignore_index=True
        )
# Out:
# No files found for Organoid Colocalization. Please check the directory.
# No files found for Cell AreaSize_Shape. Please check the directory.
# No files found for Cell Colocalization. Please check the directory.
# No files found for Cell Intensity. Please check the directory.
# No files found for Cell Granularity. Please check the directory.
# No files found for Cell Texture. Please check the directory.
# No files found for Cytoplasm AreaSize_Shape. Please check the directory.
# No files found for Cytoplasm Colocalization. Please check the directory.
# No files found for Cytoplasm Intensity. Please check the directory.
# No files found for Cytoplasm Granularity. Please check the directory.
# No files found for Cytoplasm Texture. Please check the directory.

# %%
conn = sqlite3.connect(sqlite_path)
# merge all the feature types into one dataframe
for compartment in merged_df_dict.keys():
    merged_df = pd.DataFrame(
        {
            "object_id": [],
            "image_set": [],
        }
    )
    for feature_type, feature_type_df in merged_df_dict[compartment].items():
        if len(feature_type_df) > 0:

            merged_df = pd.merge(
                merged_df,
                feature_type_df,
                on=["object_id", "image_set"],
                how="outer",
            )
        else:
            print(f"Dataframe {feature_type} is empty")
            continue

    merged_df.to_sql(
        f"{compartment}",
        conn,
        if_exists="replace",
        index=False,
    )
conn.close()
# Out:
# Dataframe Colocalization is empty
# (1, 80)
# Dataframe AreaSize_Shape is empty
# Dataframe Colocalization is empty
# Dataframe Intensity is empty
# Dataframe Granularity is empty
# Dataframe Texture is empty
# (88, 4)
# (84, 97)
# Dataframe AreaSize_Shape is empty
# Dataframe Colocalization is empty
# Dataframe Intensity is empty
# Dataframe Granularity is empty
# Dataframe Texture is empty
# (420, 4)
