# %% [markdown]
# This notebook performs profile aggregation.

# %%
import argparse
import pathlib

import pandas as pd
from pycytominer import aggregate

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "SARCO361"

# %%
# pathing
sc_fs_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/4.feature_selected_profiles/sc_fs.parquet"
).resolve(strict=True)
organoid_fs_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/4.feature_selected_profiles/organoid_fs.parquet"
).resolve(strict=True)


# output path
sc_agg_well_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_agg_well_level.parquet"
).resolve()
sc_agg_well_parent_organoid_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_agg_parent_organoid_level.parquet"
).resolve()
sc_consensus_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_consensus.parquet"
).resolve()

organoid_agg_well_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/organoid_agg_well_level.parquet"
).resolve()
organoid_consensus_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/organoid_consensus.parquet"
).resolve()

organoid_consensus_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_fs = pd.read_parquet(sc_fs_path)
organoid_fs = pd.read_parquet(organoid_fs_path)

# %% [markdown]
# ### Aggregate the single cell profiles
# We will aggregated with a few different stratifications:
# 1. Well
# 2. Well and parent organoid
# 3. Treatment - i.e. the consensus profile for each treatment

# %%
sc_fs.head()
# Out:
#     patient  object_id unit  dose   treatment image_set  \
# 0  SARCO361         63   uM     1   Nilotinib      F6-4
# 1  SARCO361        127   uM     1   Nilotinib      F6-4
# 2  SARCO361        191   uM     1   Nilotinib      F6-4
# 3  SARCO361         19   uM     1  Everolimus      C5-4
# 4  SARCO361         39   uM     1  Everolimus      C5-4
#
#                       Target           Class Therapeutic Categories Well  ...  \
# 0  tyrosine kinase inhibitor  Small Molecule        Investigational   F6  ...
# 1  tyrosine kinase inhibitor  Small Molecule        Investigational   F6  ...
# 2  tyrosine kinase inhibitor  Small Molecule        Investigational   F6  ...
# 3             mTOR inhibitor  Small Molecule       Kinase Inhibitor   C5  ...
# 4             mTOR inhibitor  Small Molecule       Kinase Inhibitor   C5  ...
#
#    Granularity_Cytoplasm_BF_GRANULARITY.2  \
# 0                                0.177022
# 1                                0.181449
# 2                                0.166467
# 3                                0.186102
# 4                                0.192541
#
#    Texture_Cytoplasm_AGP_Angular.Second.Moment_256.3  \
# 0                                          -0.238446
# 1                                          -0.815101
# 2                                           0.152044
# 3                                           0.778623
# 4                                           0.761778
#
#    Texture_Cytoplasm_AGP_Sum.Variance_256.3  \
# 0                                 -0.244723
# 1                                  0.477238
# 2                                 -0.789297
# 3                                 -0.414778
# 4                                 -0.081625
#
#    Texture_Cytoplasm_BF_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -0.902567
# 1                                          -1.425577
# 2                                           1.194696
# 3                                          -0.551235
# 4                                          -0.278053
#
#    Texture_Cytoplasm_BF_Sum.Variance_256.3  \
# 0                                 0.672952
# 1                                 1.158644
# 2                                -0.133684
# 3                                -0.906984
# 4                                -0.662951
#
#    Texture_Cytoplasm_DNA_Contrast_256.3  \
# 0                              0.002280
# 1                              0.226669
# 2                              1.315882
# 3                             -0.896620
# 4                             -0.770010
#
#    Texture_Cytoplasm_DNA_Correlation_256.3  \
# 0                                 0.034022
# 1                                 1.210875
# 2                                -1.100122
# 3                                 0.324211
# 4                                 0.343953
#
#    Texture_Cytoplasm_DNA_Sum.Variance_256.3  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                                 -0.210443                          1.447654
# 1                                  0.752661                          1.797869
# 2                                 -0.027451                          0.303446
# 3                                 -0.662453                         -1.005302
# 4                                 -0.571636                         -1.477648
#
#    Area.Size.Shape_Cytoplasm_EULER.NUMBER
# 0                                0.029134
# 1                               -0.810362
# 2                               -0.250698
# 3                                0.308966
# 4                               -3.888512
#
# [5 rows x 204 columns]

# %%
sc_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "Target",
    "Class",
    "Therapeutic Categories",
    "image_set",
    "Well",
    "parent_organoid",
]
sc_features_columns = [col for col in sc_fs.columns if col not in sc_metadata_columns]
sc_features_df = sc_fs.drop(columns=sc_metadata_columns, errors="ignore")

# %%
# stratification approach #1
sc_well_agg = aggregate(
    population_df=sc_fs,
    strata=["Well", "treatment", "Target", "Class", "Therapeutic Categories"],
    features=sc_features_columns,
    operation="median",
)
sc_well_agg.to_parquet(sc_agg_well_output_path, index=False)

# stratification approach #2
sc_well_parent_organoid_agg = aggregate(
    population_df=sc_fs,
    strata=[
        "Well",
        "parent_organoid",
        "treatment",
        "Target",
        "Class",
        "Therapeutic Categories",
    ],
    features=sc_features_columns,
    operation="median",
)
sc_well_parent_organoid_agg.to_parquet(
    sc_agg_well_parent_organoid_output_path, index=False
)
# stratification approach #3
sc_consensus = aggregate(  # a.k.a. consensus
    population_df=sc_fs,
    strata=["treatment", "Target", "Class", "Therapeutic Categories"],
    features=sc_features_columns,
    operation="median",
)
sc_consensus.to_parquet(sc_consensus_output_path, index=False)

# %% [markdown]
# ### Aggregate the organoid profiles
# We will aggregated with a few different stratifications:
# 1. Well
# 2. Treatment - i.e. the consensus profile for each treatment

# %%
organoid_fs.head()
# Out:
#     patient  object_id unit  dose    treatment image_set  \
# 0  SARCO361          3   uM     1  Selumetinib     G10-7
# 1  SARCO361         12   uM     1    Nilotinib      F6-4
# 2  SARCO361          3   uM    10  Binimetinib      C8-7
# 3  SARCO361         45   uM     1   Everolimus      C5-4
# 4  SARCO361          5   uM    10   Trametinib     F10-3
#
#                       Target           Class Therapeutic Categories Well  ...  \
# 0           MEK1/2 inhibitor  Small Molecule       Kinase Inhibitor  G10  ...
# 1  tyrosine kinase inhibitor  Small Molecule        Investigational   F6  ...
# 2           MEK1/2 inhibitor  Small Molecule       Kinase Inhibitor   C8  ...
# 3             mTOR inhibitor  Small Molecule       Kinase Inhibitor   C5  ...
# 4           MEK1/2 inhibitor  Small Molecule       Kinase Inhibitor  F10  ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                -1.109763
# 1                                -1.107423
# 2                                -1.109387
# 3                                 0.651113
# 4                                -0.935827
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                           -0.947271                              -1.076803
# 1                           -0.912819                              -1.075108
# 2                           -0.942641                              -1.076499
# 3                           -0.215303                               0.042700
# 4                           -0.537656                              -0.892315
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.786205                             -0.851938
# 1                           -0.780288                             -0.833558
# 2                           -0.785398                             -0.849212
# 3                           -0.209479                              0.447558
# 4                           -0.535576                             -0.417425
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -1.127175
# 1                                -1.125750
# 2                                -1.126907
# 3                                 0.588238
# 4                                -0.906514
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                             -0.957166                        -0.848919
# 1                             -0.952059                        -1.243540
# 2                             -0.956399                        -1.214684
# 3                              0.648497                        -0.180141
# 4                             -0.523087                         2.951274
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.187277
# 1                               3.975833
# 2                               2.726900
# 3                              -0.365696
# 4                              -0.544115
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -1.168251
# 1                              -1.145283
# 2                              -1.155802
# 3                               2.178146
# 4                              -1.131081
#
# [5 rows x 154 columns]

# %%
organoid_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "image_set",
    "Target",
    "Class",
    "Therapeutic Categories",
    "Well",
    "parent_organoid",
    "MOA",
]
organoidfeatures_columns = [
    col for col in organoid_fs.columns if col not in organoid_metadata_columns
]
organoid_features_df = organoid_fs.drop(columns=sc_metadata_columns, errors="ignore")

# %%
# stratification approach #1
organoid_well_agg = aggregate(
    population_df=organoid_fs,
    strata=["Well", "treatment", "Target", "Class", "Therapeutic Categories"],
    features=organoidfeatures_columns,
    operation="median",
)
organoid_well_agg.to_parquet(organoid_agg_well_output_path, index=False)

# stratification approach #2
organoid_consensus = aggregate(  # a.k.a. consensus
    population_df=organoid_fs,
    strata=["treatment", "Target", "Class", "Therapeutic Categories"],
    features=organoidfeatures_columns,
    operation="median",
)
organoid_consensus.to_parquet(organoid_consensus_output_path, index=False)

# %%
organoid_well_agg.head()
# Out:
#   Well       treatment            Target           Class  \
# 0  C10      Trametinib  MEK1/2 inhibitor  Small Molecule
# 1  C11  Staurosporine                NaN             NaN
# 2   C2  Staurosporine                NaN             NaN
# 3   C3       Onalespib   HSP90 inhibitor  Small Molecule
# 4   C4            DMSO           Control         Control
#
#   Therapeutic Categories  single_cell_count  \
# 0       Kinase Inhibitor                NaN
# 1                    NaN                6.0
# 2                    NaN                1.0
# 3        Investigational                6.0
# 4                Control                6.0
#
#    Colocalization_Organoid_AGP.BF_MAX.CORRELATION.COEFF  \
# 0                                          -0.702124
# 1                                          -0.142355
# 2                                           0.159843
# 3                                          -0.223045
# 4                                          -0.096943
#
#    Colocalization_Organoid_AGP.BF_MIN.MANDERS.COEFF.M2  \
# 0                                          -0.111418
# 1                                           0.147213
# 2                                          -0.721864
# 3                                          -0.551922
# 4                                           0.717542
#
#    Colocalization_Organoid_AGP.BF_MIN.OVERLAP.COEFF  \
# 0                                         -0.378393
# 1                                         -0.438721
# 2                                         -0.521371
# 3                                         -0.240660
# 4                                         -0.142120
#
#    Colocalization_Organoid_AGP.BF_MIN.K2  ...  \
# 0                               0.975233  ...
# 1                               0.772732  ...
# 2                              -0.097855  ...
# 3                               0.002510  ...
# 4                              -0.385034  ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                -0.895035
# 1                                -0.250226
# 2                                -0.756240
# 3                                -0.917505
# 4                                -0.469886
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                            0.474909                              -0.476254
# 1                           -0.322065                              -0.003127
# 2                           -0.509780                              -0.722410
# 3                           -0.408504                              -0.856135
# 4                            0.269059                              -0.616152
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.388394                              0.617448
# 1                            0.007014                             -0.021853
# 2                           -0.690430                              0.035457
# 3                           -0.622091                              0.016535
# 4                           -0.122494                             -0.500012
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.543824
# 1                                 0.437657
# 2                                -0.470381
# 3                                -0.705885
# 4                                -0.707071
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                             -0.304456                         0.589525
# 1                              0.308168                         2.333730
# 2                             -0.592172                        -0.647005
# 3                             -0.420016                        -0.554384
# 4                             -0.495633                        -0.335279
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.276486
# 1                              -0.544115
# 2                               1.240075
# 3                               0.110088
# 4                              -0.425169
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -0.218371
# 1                              -0.806159
# 2                              -0.663832
# 3                              -0.697587
# 4                              -0.739511
#
# [5 rows x 149 columns]

# %%
organoid_consensus.head()
# Out:
#       treatment                              Target           Class  \
# 0   Binimetinib                    MEK1/2 inhibitor  Small Molecule
# 1  Cabozantinib  receptor tyrosine kinase inhibitor  Small Molecule
# 2    Copanlisib                      PI3K inhibitor  Small Molecule
# 3          DMSO                             Control         Control
# 4       Digoxin               Na+/K+ pump inhibitor  Small Molecule
#
#   Therapeutic Categories  single_cell_count  \
# 0       Kinase Inhibitor                2.0
# 1       Kinase Inhibitor                6.0
# 2       Kinase Inhibitor                3.0
# 3                Control                5.5
# 4     Cardiac Glycosides                3.5
#
#    Colocalization_Organoid_AGP.BF_MAX.CORRELATION.COEFF  \
# 0                                           0.108556
# 1                                          -0.242231
# 2                                           0.152561
# 3                                           0.007301
# 4                                           0.148600
#
#    Colocalization_Organoid_AGP.BF_MIN.MANDERS.COEFF.M2  \
# 0                                          -0.059387
# 1                                          -0.509574
# 2                                          -0.507652
# 3                                          -0.260941
# 4                                           0.371397
#
#    Colocalization_Organoid_AGP.BF_MIN.OVERLAP.COEFF  \
# 0                                         -0.273709
# 1                                         -0.201770
# 2                                         -0.604403
# 3                                         -0.223622
# 4                                         -0.452256
#
#    Colocalization_Organoid_AGP.BF_MIN.K2  \
# 0                              -0.212329
# 1                              -0.189627
# 2                              -0.324748
# 3                              -0.290239
# 4                               0.035579
#
#    Colocalization_Organoid_AGP.BF_MEAN.MANDERS.COEFF.COSTES.M1  ...  \
# 0                                          -0.582425            ...
# 1                                          -0.580275            ...
# 2                                          -0.524391            ...
# 3                                          -0.578616            ...
# 4                                          -0.581458            ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                -0.515496
# 1                                -0.490876
# 2                                -0.797712
# 3                                -0.175090
# 4                                -0.737107
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                           -0.379363                              -0.473104
# 1                            0.017371                              -0.394175
# 2                           -0.748342                              -0.734517
# 3                           -0.335327                              -0.075388
# 4                           -0.623579                              -0.713981
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.292845                             -0.105459
# 1                           -0.177493                              0.060618
# 2                           -0.633432                             -0.345864
# 3                           -0.237172                             -0.433695
# 4                           -0.595866                             -0.480576
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.434973
# 1                                -0.264256
# 2                                -0.565164
# 3                                -0.227000
# 4                                -0.495751
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                             -0.252780                         1.158796
# 1                             -0.031876                        -0.521060
# 2                             -0.573768                         0.625863
# 3                             -0.452151                        -0.315895
# 4                             -0.575939                         1.664419
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.484642
# 1                              -0.306223
# 2                              -0.484642
# 3                              -0.425169
# 4                              -0.484642
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -0.787673
# 1                              -0.169901
# 2                              -0.922188
# 3                              -0.256043
# 4                              -0.809067
#
# [5 rows x 148 columns]
