# %% [markdown]
# This notebook performs profile aggregation.

# %%
import argparse
import pathlib

import pandas as pd
from pycytominer import aggregate

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "SARCO361"

# %% [markdown]
# ### Merge the sc and organoid profiles after aggregation
# 1. The single-cell parent organoid aggregated profile is merged with the fs organoid profile
# 2. The well level profiles are merged together
# 3. The consensus profiles are merged together

# %%
# group the import paths by the type of aggregation
#######################################################################
# 1. The single-cell parent organoid aggregated profile is merged with the fs organoid profile
organoid_fs_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/4.feature_selected_profiles/organoid_fs.parquet"
).resolve(strict=True)
sc_agg_well_parent_organoid_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_agg_parent_organoid_level.parquet"
).resolve(strict=True)

# output merged path
organoid_agg_well_parent_organoid_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/6.merged_profiles/sc-organoid_sc_agg_well_parent_organoid_level.parquet"
).resolve()

########################################################################

# 2. The well level profiles are merged together
sc_agg_well_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_agg_well_level.parquet"
).resolve(strict=True)

organoid_agg_well_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/organoid_agg_well_level.parquet"
).resolve(strict=True)

# output merged path
organoid_agg_well_merge_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/6.merged_profiles/sc-organoid_agg_well_level.parquet"
).resolve()

###################################################################################

# 3. The consensus profiles are merged together

sc_consensus_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/sc_consensus.parquet"
).resolve(strict=True)

organoid_consensus_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/5.aggregated_profiles/organoid_consensus.parquet"
).resolve(strict=True)

# output merged path
organoid_consensus_merge_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/6.merged_profiles/sc-organoid_consensus.parquet"
).resolve()


organoid_consensus_merge_path.parent.mkdir(parents=True, exist_ok=True)

###############################################################################

# %%
organoid_fs = pd.read_parquet(organoid_fs_path)
sc_agg_well_parent_organoid = pd.read_parquet(sc_agg_well_parent_organoid_path)
sc_agg_well_parent_organoid_merge = sc_agg_well_parent_organoid.merge(
    organoid_fs,
    left_on=[
        "Well",
        "parent_organoid",
        "treatment",
        "Target",
        "Class",
        "Therapeutic Categories",
    ],
    right_on=[
        "Well",
        "object_id",
        "treatment",
        "Target",
        "Class",
        "Therapeutic Categories",
    ],
)

sc_agg_well_parent_organoid_merge.to_parquet(
    organoid_agg_well_parent_organoid_path, index=False
)
sc_agg_well_parent_organoid_merge.head()
# Out:
#   Well  parent_organoid       treatment           Target           Class  \
# 0  C11               20  Staurosporine              None            None
# 1   C2               21  Staurosporine              None            None
# 2   C3               11       Onalespib  HSP90 inhibitor  Small Molecule
# 3   C3               28       Onalespib  HSP90 inhibitor  Small Molecule
# 4   C4                8            DMSO          Control         Control
#
#   Therapeutic Categories  \
# 0                   None
# 1                   None
# 2        Investigational
# 3        Investigational
# 4                Control
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  \
# 0                                          -0.382848
# 1                                           0.626485
# 2                                          -0.461062
# 3                                          -0.822280
# 4                                          -0.085559
#
#    Colocalization_Nuclei_AGP.BF_MAX.OVERLAP.COEFF  \
# 0                                       -0.069718
# 1                                       -0.183051
# 2                                       -0.166454
# 3                                       -0.141761
# 4                                       -0.138928
#
#    Colocalization_Nuclei_AGP.BF_MAX.K1  \
# 0                             0.774137
# 1                            -0.380016
# 2                            -0.145549
# 3                             0.028849
# 4                             0.164228
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  ...  \
# 0                                          -0.128457         ...
# 1                                           0.882015         ...
# 2                                          -1.138929         ...
# 3                                          -1.138929         ...
# 4                                           0.882015         ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                 0.198379
# 1                                -0.874566
# 2                                -0.651099
# 3                                -0.623361
# 4                                -0.394264
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                           -0.488562                               0.944171
# 1                           -0.803983                              -0.856086
# 2                            1.091993                               0.023342
# 3                           -0.865889                              -0.803374
# 4                            0.546128                              -0.684949
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                            0.666372                             -0.533178
# 1                           -0.745645                             -0.580098
# 2                           -0.079483                              0.016535
# 3                           -0.759290                              0.728670
# 4                           -0.007817                             -0.256007
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                 0.722882
# 1                                -0.726909
# 2                                -0.304982
# 3                                 0.295029
# 4                                -0.845391
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                              0.700276                         2.333730
# 1                             -0.829121                        -0.745075
# 2                             -0.420016                        -0.554384
# 3                             -0.079904                        -0.605582
# 4                             -0.469627                        -0.942827
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.544115
# 1                               1.240075
# 2                               0.110088
# 3                               0.288507
# 4                              -0.127804
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -0.642648
# 1                               0.926309
# 2                               0.751681
# 3                               1.633384
# 4                              -0.798269
#
# [5 rows x 348 columns]

# %%
sc_agg_well = pd.read_parquet(sc_agg_well_path)
organoid_agg_well = pd.read_parquet(organoid_agg_well_path)
sc_agg_well_merge = sc_agg_well.merge(
    organoid_agg_well,
    on=["Well", "treatment", "Target", "Class", "Therapeutic Categories"],
)
sc_agg_well_merge.to_parquet(organoid_agg_well_merge_path, index=False)
sc_agg_well_merge.head()
# Out:
#   Well       treatment            Target           Class  \
# 0  C10      Trametinib  MEK1/2 inhibitor  Small Molecule
# 1  C11  Staurosporine               None            None
# 2   C2  Staurosporine               None            None
# 3   C3       Onalespib   HSP90 inhibitor  Small Molecule
# 4   C4            DMSO           Control         Control
#
#   Therapeutic Categories  \
# 0       Kinase Inhibitor
# 1                   None
# 2                   None
# 3        Investigational
# 4                Control
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  \
# 0                                           0.559485
# 1                                          -0.382848
# 2                                          -0.212091
# 3                                          -0.123717
# 4                                          -0.137224
#
#    Colocalization_Nuclei_AGP.BF_MAX.OVERLAP.COEFF  \
# 0                                       -0.162935
# 1                                       -0.069718
# 2                                       -0.170930
# 3                                       -0.161116
# 4                                       -0.171965
#
#    Colocalization_Nuclei_AGP.BF_MAX.K1  \
# 0                            -0.073120
# 1                             0.774137
# 2                            -0.208814
# 3                            -0.072546
# 4                            -0.178687
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.882015
# 1                                          -0.128457
# 2                                          -1.138929
# 3                                          -1.138929
# 4                                           0.882015
#
#    Colocalization_Nuclei_AGP.ER_MAX.CORRELATION.COEFF  ...  \
# 0                                          -0.052205   ...
# 1                                           1.459290   ...
# 2                                           0.497327   ...
# 3                                           0.392228   ...
# 4                                           0.790491   ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                -0.895035
# 1                                -0.250226
# 2                                -0.756240
# 3                                -0.917505
# 4                                -0.469886
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                            0.474909                              -0.476254
# 1                           -0.322065                              -0.003127
# 2                           -0.509780                              -0.722410
# 3                           -0.408504                              -0.856135
# 4                            0.269059                              -0.616152
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.388394                              0.617448
# 1                            0.007014                             -0.021853
# 2                           -0.690430                              0.035457
# 3                           -0.622091                              0.016535
# 4                           -0.122494                             -0.500012
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.543824
# 1                                 0.437657
# 2                                -0.470381
# 3                                -0.705885
# 4                                -0.707071
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                             -0.304456                         0.589525
# 1                              0.308168                         2.333730
# 2                             -0.592172                        -0.647005
# 3                             -0.420016                        -0.554384
# 4                             -0.495633                        -0.335279
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.276486
# 1                              -0.544115
# 2                               1.240075
# 3                               0.110088
# 4                              -0.425169
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -0.218371
# 1                              -0.806159
# 2                              -0.663832
# 3                              -0.697587
# 4                              -0.739511
#
# [5 rows x 342 columns]

# %%
sc_consensus = pd.read_parquet(sc_consensus_path)
organoid_consensus = pd.read_parquet(organoid_consensus_path)
sc_consensus_merge = sc_consensus.merge(
    organoid_consensus, on=["treatment", "Target", "Class", "Therapeutic Categories"]
)
sc_consensus_merge.to_parquet(organoid_consensus_merge_path, index=False)
sc_consensus_merge.head()
# Out:
#       treatment                              Target           Class  \
# 0   Binimetinib                    MEK1/2 inhibitor  Small Molecule
# 1  Cabozantinib  receptor tyrosine kinase inhibitor  Small Molecule
# 2    Copanlisib                      PI3K inhibitor  Small Molecule
# 3          DMSO                             Control         Control
# 4       Digoxin               Na+/K+ pump inhibitor  Small Molecule
#
#   Therapeutic Categories  \
# 0       Kinase Inhibitor
# 1       Kinase Inhibitor
# 2       Kinase Inhibitor
# 3                Control
# 4     Cardiac Glycosides
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  \
# 0                                           0.032436
# 1                                          -0.364900
# 2                                          -0.168606
# 3                                           0.023943
# 4                                          -0.177425
#
#    Colocalization_Nuclei_AGP.BF_MAX.OVERLAP.COEFF  \
# 0                                       -0.171403
# 1                                       -0.157860
# 2                                       -0.174040
# 3                                       -0.167206
# 4                                       -0.164186
#
#    Colocalization_Nuclei_AGP.BF_MAX.K1  \
# 0                            -0.167520
# 1                            -0.142479
# 2                            -0.221283
# 3                            -0.187586
# 4                            -0.128185
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.882015
# 1                                          -1.138929
# 2                                          -1.120369
# 3                                           0.882015
# 4                                          -0.128457
#
#    Colocalization_Nuclei_AGP.ER_MAX.CORRELATION.COEFF  \
# 0                                          -0.327304
# 1                                          -0.514006
# 2                                           0.131832
# 3                                           0.034922
# 4                                          -0.571223
#
#    Colocalization_Nuclei_AGP.ER_MAX.OVERLAP.COEFF  ...  \
# 0                                       -0.169844  ...
# 1                                       -0.106318  ...
# 2                                       -0.145366  ...
# 3                                       -0.165495  ...
# 4                                       -0.152403  ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                -0.515496
# 1                                -0.490876
# 2                                -0.797712
# 3                                -0.175090
# 4                                -0.737107
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                           -0.379363                              -0.473104
# 1                            0.017371                              -0.394175
# 2                           -0.748342                              -0.734517
# 3                           -0.335327                              -0.075388
# 4                           -0.623579                              -0.713981
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.292845                             -0.105459
# 1                           -0.177493                              0.060618
# 2                           -0.633432                             -0.345864
# 3                           -0.237172                             -0.433695
# 4                           -0.595866                             -0.480576
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -0.434973
# 1                                -0.264256
# 2                                -0.565164
# 3                                -0.227000
# 4                                -0.495751
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                             -0.252780                         1.158796
# 1                             -0.031876                        -0.521060
# 2                             -0.573768                         0.625863
# 3                             -0.452151                        -0.315895
# 4                             -0.575939                         1.664419
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                              -0.484642
# 1                              -0.306223
# 2                              -0.484642
# 3                              -0.425169
# 4                              -0.484642
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -0.787673
# 1                              -0.169901
# 2                              -0.922188
# 3                              -0.256043
# 4                              -0.809067
#
# [5 rows x 341 columns]
