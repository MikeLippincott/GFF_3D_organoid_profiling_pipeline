# %% [markdown]
# This notebook performs profile aggregation.

# %%
import argparse
import pathlib

import pandas as pd
from pycytominer import aggregate

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "NF0014"

# %% [markdown]
# ### Merge the sc and organoid profiles after aggregation
# 1. The single-cell parent organoid aggregated profile is merged with the fs organoid profile
# 2. The well level profiles are merged together
# 3. The consensus profiles are merged together

# %%
# group the import paths by the type of aggregation
#######################################################################
# 1. The single-cell parent organoid aggregated profile is merged with the fs organoid profile
organoid_fs_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/3.organoid_fs_profiles.parquet"
).resolve(strict=True)
sc_agg_well_parent_organoid_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/4.sc_agg_well_parent_organoid_level_profiles.parquet"
).resolve(strict=True)

# ouput merged path
organoid_agg_well_parent_organoid_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/5.sc-organoid-sc_well_agg_parent_organoid_level_profiles.parquet"
).resolve()

########################################################################

# 2. The well level profiles are merged together
sc_agg_well_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/4.sc_agg_well_level_profiles.parquet"
).resolve(strict=True)

organoid_agg_well_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/4.organoid_agg_well_level_profiles.parquet"
).resolve(strict=True)

# output merged path
organoid_agg_well_merge_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/5.sc-organoid-sc_well_agg_merge_profiles.parquet"
).resolve()

###################################################################################

# 3. The consensus profiles are merged together

sc_consensus_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/4.sc_consensus_profiles.parquet"
).resolve(strict=True)

organoid_consensus_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/4.organoid_consensus_profiles.parquet"
).resolve(strict=True)

# output merged path
organoid_consensus_merge_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/5.sc-organoid_consensus_profiles.parquet"
).resolve()

###############################################################################

# %%
organoid_fs = pd.read_parquet(organoid_fs_path)
sc_agg_well_parent_organoid = pd.read_parquet(sc_agg_well_parent_organoid_path)
sc_agg_well_parent_organoid_merge = sc_agg_well_parent_organoid.merge(
    organoid_fs,
    left_on=["Well", "parent_organoid"],
    right_on=["Well", "object_id"],
)

sc_agg_well_parent_organoid_merge.to_parquet(
    organoid_agg_well_parent_organoid_path, index=False
)
sc_agg_well_parent_organoid_merge.head()
# Out:
#   Well  parent_organoid  Area.Size.Shape_Nuclei_EXTENT  \
# 0  C10               20                       0.032530
# 1  C10               44                       0.260439
# 2  C11               24                       1.069454
# 3  C11               30                       0.756402
# 4   C2                6                      -0.944134
#
#    Colocalization_Nuclei_AGP.BF_MIN.CORRELATION.COEFF  \
# 0                                           0.474660
# 1                                           0.272242
# 2                                          -1.096034
# 3                                          -1.176695
# 4                                          -0.111287
#
#    Colocalization_Nuclei_AGP.BF_MIN.OVERLAP.COEFF  \
# 0                                       -0.225378
# 1                                       -0.224774
# 2                                       -0.224948
# 3                                       -0.225016
# 4                                       -0.213888
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.K2  \
# 0                                0.439943
# 1                                0.400522
# 2                                0.167213
# 3                                0.353732
# 4                                1.727864
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.217904
# 1                                           0.871180
# 2                                          -1.325093
# 3                                          -1.325093
# 4                                          -1.291833
#
#    Colocalization_Nuclei_AGP.ER_MEAN.CORRELATION.COEFF  \
# 0                                           0.333916
# 1                                          -0.443557
# 2                                           1.615419
# 3                                           1.460497
# 4                                           2.149684
#
#    Colocalization_Nuclei_AGP.ER_MEDIAN.OVERLAP.COEFF  \
# 0                                          -0.121818
# 1                                          -0.127671
# 2                                          -0.128931
# 3                                          -0.129286
# 4                                          -0.130097
#
#    Colocalization_Nuclei_AGP.ER_MEAN.K1  ...  \
# 0                             -0.465793  ...
# 1                             -0.691352  ...
# 2                             -0.526353  ...
# 3                             -0.604075  ...
# 4                             -0.828387  ...
#
#    Texture_Organoid_BF_Variance_256.1  Texture_Organoid_DNA_Contrast_256.1  \
# 0                           -2.144830                            -0.791422
# 1                           -1.262567                            -0.947948
# 2                           -1.492940                            -1.238702
# 3                           -1.045857                            -1.218586
# 4                           -1.392898                            -0.576882
#
#    Texture_Organoid_DNA_Variance_256.1  Texture_Organoid_ER_Contrast_256.1  \
# 0                            -1.250711                           -0.624226
# 1                            -0.761610                           -0.677544
# 2                            -1.289316                           -0.571080
# 3                            -1.249619                           -0.598743
# 4                            -0.537603                           -0.684635
#
#    Texture_Organoid_ER_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -2.119960
# 1                                          -1.477256
# 2                                          -2.782956
# 3                                          -2.739134
# 4                                          -1.928213
#
#    Texture_Organoid_ER_Sum.Average_256.1  Texture_Organoid_ER_Variance_256.1  \
# 0                              -1.379050                           -0.951777
# 1                              -0.965806                           -0.764784
# 2                              -1.053659                           -0.785330
# 3                              -1.073709                           -0.834201
# 4                              -1.240097                           -0.975188
#
#    Texture_Organoid_Mito_Contrast_256.1  \
# 0                             -0.543091
# 1                             -0.740854
# 2                             -0.505358
# 3                             -0.341980
# 4                             -0.877364
#
#    Texture_Organoid_Mito_Sum.Average_256.1  \
# 0                                -1.493870
# 1                                -0.423390
# 2                                -0.791390
# 3                                -0.647428
# 4                                -1.217033
#
#    Texture_Organoid_Mito_Variance_256.1
# 0                             -0.814296
# 1                              0.345606
# 2                             -0.147683
# 3                             -0.001812
# 4                             -0.870099
#
# [5 rows x 443 columns]

# %%
sc_agg_well = pd.read_parquet(sc_agg_well_path)
organoid_agg_well = pd.read_parquet(organoid_agg_well_path)
sc_agg_well_merge = sc_agg_well.merge(
    organoid_agg_well,
    on=["Well"],
)
sc_agg_well_merge.to_parquet(organoid_agg_well_merge_path, index=False)
sc_agg_well_merge.head()
# Out:
#   Well  Area.Size.Shape_Nuclei_EXTENT  \
# 0  C10                       0.249550
# 1  C11                       0.912928
# 2   C2                      -0.944134
# 3   C3                      -0.094436
# 4   C4                       0.440495
#
#    Colocalization_Nuclei_AGP.BF_MIN.CORRELATION.COEFF  \
# 0                                           0.169837
# 1                                          -1.136364
# 2                                          -0.111287
# 3                                          -0.262012
# 4                                          -0.035523
#
#    Colocalization_Nuclei_AGP.BF_MIN.OVERLAP.COEFF  \
# 0                                       -0.224742
# 1                                       -0.225000
# 2                                       -0.213888
# 3                                       -0.224826
# 4                                       -0.224660
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.K2  \
# 0                                0.651267
# 1                                0.251055
# 2                                1.727864
# 3                               -0.205275
# 4                               -0.238421
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.083261
# 1                                          -1.325093
# 2                                          -1.291833
# 3                                          -0.339518
# 4                                           0.871217
#
#    Colocalization_Nuclei_AGP.ER_MEAN.CORRELATION.COEFF  \
# 0                                          -0.439232
# 1                                           1.537958
# 2                                           2.149684
# 3                                           1.192060
# 4                                          -0.094054
#
#    Colocalization_Nuclei_AGP.ER_MEDIAN.OVERLAP.COEFF  \
# 0                                          -0.127535
# 1                                          -0.129109
# 2                                          -0.130097
# 3                                          -0.129253
# 4                                          -0.107299
#
#    Colocalization_Nuclei_AGP.ER_MEAN.K1  Colocalization_Nuclei_AGP.ER_MIN.K2  \
# 0                             -0.647980                            -0.321009
# 1                             -0.589686                            -1.383946
# 2                             -0.828387                            -0.813906
# 3                             -0.588332                            -0.915991
# 4                             -0.095976                             0.129004
#
#    ...  Texture_Organoid_BF_Variance_256.1  \
# 0  ...                           -1.703699
# 1  ...                           -1.269399
# 2  ...                           -1.392898
# 3  ...                           -0.498791
# 4  ...                            0.925085
#
#    Texture_Organoid_DNA_Contrast_256.1  Texture_Organoid_DNA_Variance_256.1  \
# 0                            -0.869685                            -1.006161
# 1                            -1.228644                            -1.269467
# 2                            -0.576882                            -0.537603
# 3                            -0.433155                            -1.183203
# 4                             1.720782                             1.271465
#
#    Texture_Organoid_ER_Contrast_256.1  \
# 0                           -0.650885
# 1                           -0.584912
# 2                           -0.684635
# 3                           -0.287713
# 4                            1.513276
#
#    Texture_Organoid_ER_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -1.798608
# 1                                          -2.761045
# 2                                          -1.928213
# 3                                           0.077690
# 4                                           1.033728
#
#    Texture_Organoid_ER_Sum.Average_256.1  Texture_Organoid_ER_Variance_256.1  \
# 0                              -1.172428                           -0.858280
# 1                              -1.063684                           -0.809766
# 2                              -1.240097                           -0.975188
# 3                              -0.670042                           -0.886138
# 4                               0.756794                            0.302486
#
#    Texture_Organoid_Mito_Contrast_256.1  \
# 0                             -0.641972
# 1                             -0.423669
# 2                             -0.877364
# 3                              1.740250
# 4                             -0.537314
#
#    Texture_Organoid_Mito_Sum.Average_256.1  \
# 0                                -0.958630
# 1                                -0.719409
# 2                                -1.217033
# 3                                 0.388875
# 4                                -0.741116
#
#    Texture_Organoid_Mito_Variance_256.1
# 0                             -0.234345
# 1                             -0.074747
# 2                             -0.870099
# 3                             -0.328403
# 4                             -1.032983
#
# [5 rows x 436 columns]

# %%
sc_consensus = pd.read_parquet(sc_consensus_path)
organoid_consensus = pd.read_parquet(organoid_consensus_path)
sc_consensus_merge = sc_consensus.merge(organoid_consensus, on=["treatment"])
sc_consensus_merge.to_parquet(organoid_consensus_merge_path, index=False)
sc_consensus_merge.head()
# Out:
#       treatment  Area.Size.Shape_Nuclei_EXTENT  \
# 0   Binimetinib                       0.275096
# 1  Cabozantinib                       0.329180
# 2    Copanlisib                       0.382810
# 3          DMSO                       0.358735
# 4       Digoxin                       0.456005
#
#    Colocalization_Nuclei_AGP.BF_MIN.CORRELATION.COEFF  \
# 0                                          -0.154379
# 1                                          -0.142624
# 2                                          -0.022008
# 3                                           0.015825
# 4                                          -0.002706
#
#    Colocalization_Nuclei_AGP.BF_MIN.OVERLAP.COEFF  \
# 0                                       -0.224587
# 1                                       -0.224661
# 2                                       -0.224689
# 3                                       -0.224567
# 4                                       -0.226011
#
#    Colocalization_Nuclei_AGP.BF_MEDIAN.K2  \
# 0                                0.608598
# 1                               -0.031776
# 2                                0.885835
# 3                                0.107505
# 4                               -0.410811
#
#    Colocalization_Nuclei_AGP.BF_MIN.MANDERS.COEFF.COSTES.M1  \
# 0                                           0.053906
# 1                                          -0.331916
# 2                                          -0.027362
# 3                                           0.871217
# 4                                          -0.195338
#
#    Colocalization_Nuclei_AGP.ER_MEAN.CORRELATION.COEFF  \
# 0                                           0.500932
# 1                                           0.237225
# 2                                           0.831204
# 3                                          -0.002969
# 4                                           1.339546
#
#    Colocalization_Nuclei_AGP.ER_MEDIAN.OVERLAP.COEFF  \
# 0                                          -0.122673
# 1                                          -0.122674
# 2                                          -0.124853
# 3                                          -0.115328
# 4                                          -0.129317
#
#    Colocalization_Nuclei_AGP.ER_MEAN.K1  Colocalization_Nuclei_AGP.ER_MIN.K2  \
# 0                             -0.699251                             0.042775
# 1                             -0.612458                             0.282566
# 2                             -0.613907                            -0.322652
# 3                             -0.460623                             0.096228
# 4                             -0.380297                            -1.365735
#
#    ...  Texture_Organoid_BF_Variance_256.1  \
# 0  ...                           -0.818273
# 1  ...                           -0.639507
# 2  ...                           -1.006130
# 3  ...                           -0.002123
# 4  ...                           -0.595122
#
#    Texture_Organoid_DNA_Contrast_256.1  Texture_Organoid_DNA_Variance_256.1  \
# 0                            -0.909273                            -1.126190
# 1                            -0.928523                            -1.284898
# 2                            -0.665874                            -0.766402
# 3                            -0.358536                             0.032497
# 4                            -0.983785                            -1.291815
#
#    Texture_Organoid_ER_Contrast_256.1  \
# 0                           -0.680504
# 1                           -0.442474
# 2                           -0.401909
# 3                           -0.394669
# 4                           -0.658006
#
#    Texture_Organoid_ER_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -0.513943
# 1                                          -1.366897
# 2                                          -1.356574
# 3                                          -0.188289
# 4                                          -2.141181
#
#    Texture_Organoid_ER_Sum.Average_256.1  Texture_Organoid_ER_Variance_256.1  \
# 0                              -1.088284                           -0.907953
# 1                              -0.685942                           -0.674219
# 2                              -0.961208                           -0.762546
# 3                              -0.294784                           -0.358874
# 4                              -1.133485                           -0.956781
#
#    Texture_Organoid_Mito_Contrast_256.1  \
# 0                             -0.633646
# 1                             -0.581858
# 2                              0.440297
# 3                             -0.234232
# 4                             -0.622903
#
#    Texture_Organoid_Mito_Sum.Average_256.1  \
# 0                                -0.722304
# 1                                -0.466476
# 2                                -0.650608
# 3                                -0.194620
# 4                                -1.176740
#
#    Texture_Organoid_Mito_Variance_256.1
# 0                             -0.340528
# 1                             -0.136768
# 2                             -0.305117
# 3                             -0.409733
# 4                             -0.994933
#
# [5 rows x 436 columns]
