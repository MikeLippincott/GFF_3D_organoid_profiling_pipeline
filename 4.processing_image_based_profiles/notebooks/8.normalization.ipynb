# %% [markdown]
# This notebook performs profile normalization.
# All profiles are normalized to the DMSO control treated profiles.

# %%
import argparse
import os
import pathlib
import sys

import numpy as np
import pandas as pd
from arg_parsing_utils import parse_args
from notebook_init_utils import bandicoot_check, init_notebook
from pycytominer import normalize

root_dir, in_notebook = init_notebook()

profile_base_dir = bandicoot_check(
    pathlib.Path(os.path.expanduser("~/mnt/bandicoot")).resolve(), root_dir
)

# %%
if not in_notebook:
    args = parse_args()
    patient = args["patient"]
    image_based_profiles_subparent_name = args["image_based_profiles_subparent_name"]

else:
    patient = "NF0037_T1-Z-1"
    image_based_profiles_subparent_name = "image_based_profiles"

# %%
# pathing
sc_annotated_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/2.annotated_profiles/sc_anno.parquet"
).resolve(strict=True)
organoid_annotated_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/2.annotated_profiles/organoid_anno.parquet"
).resolve(strict=True)


# output path
sc_normalized_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/3.normalized_profiles/sc_norm.parquet"
).resolve()
organoid_normalized_output_path = pathlib.Path(
    f"{profile_base_dir}/data/{patient}/{image_based_profiles_subparent_name}/3.normalized_profiles/organoid_norm.parquet"
).resolve()

organoid_normalized_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_annotated_profiles = pd.read_parquet(sc_annotated_path)
organoid_annotated_profiles = pd.read_parquet(organoid_annotated_path)

# %%
sc_annotated_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0          NF0037_T1-Z-1                  36             %              1
# 1          NF0037_T1-Z-1                  58             %              1
# 2          NF0037_T1-Z-1                 150             %              1
# 3          NF0037_T1-Z-1                 238             %              1
# 4          NF0037_T1-Z-1                <NA>             %              1
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0            DMSO 1%               F4-2            F4
# 1            DMSO 1%               F4-2            F4
# 2            DMSO 1%               F4-2            F4
# 3            DMSO 1%               F4-2            F4
# 4            DMSO 1%               F4-3            F4
#
#    Metadata_parent_organoid  Area.Size.Shape_Nuclei_VOLUME  \
# 0                        71                        11253.0
# 1                        71                        24819.0
# 2                        71                        62608.0
# 3                        71                        19825.0
# 4                      <NA>                            NaN
#
#    Area.Size.Shape_Nuclei_CENTER.X  ...  \
# 0                      1188.314453  ...
# 1                       872.092896  ...
# 2                      1005.007263  ...
# 3                      1242.052368  ...
# 4                              NaN  ...
#
#    Texture_Cytoplasm_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.999750
# 1                                           0.998241
# 2                                           0.999460
# 3                                           0.999305
# 4                                                NaN
#
#    Texture_Cytoplasm_Mito_Sum.Average_256.3  \
# 0                                  0.044481
# 1                                  0.316644
# 2                                  0.092457
# 3                                  0.144222
# 4                                       NaN
#
#    Texture_Cytoplasm_Mito_Sum.Entropy_256.3  \
# 0                                  0.004512
# 1                                  0.029361
# 2                                  0.009423
# 3                                  0.012196
# 4                                       NaN
#
#    Texture_Cytoplasm_Mito_Sum.Variance_256.3  \
# 0                                   8.536573
# 1                                  56.377149
# 2                                  16.917697
# 3                                  30.912232
# 4                                        NaN
#
#    Texture_Cytoplasm_Mito_Variance_256.3  Metadata_Target  Metadata_Class  \
# 0                               3.043701             None            None
# 1                              16.500579             None            None
# 2                               5.618664             None            None
# 3                               9.516243             None            None
# 4                                    NaN             None            None
#
#    Metadata_Therapeutic_Categories  Metadata_patient  Metadata_tumor
# 0                             None            NF0037          T1-Z-1
# 1                             None            NF0037          T1-Z-1
# 2                             None            NF0037          T1-Z-1
# 3                             None            NF0037          T1-Z-1
# 4                             None            NF0037          T1-Z-1
#
# [5 rows x 5976 columns]

# %% [markdown]
# ### Normalize the single-cell profiles

# %%
sc_metadata_columns = [x for x in sc_annotated_profiles.columns if "Metadata" in x]

sc_metadata_columns += [
    "Area.Size.Shape_Cell_CENTER.X",
    "Area.Size.Shape_Cell_CENTER.Y",
    "Area.Size.Shape_Cell_CENTER.Z",
]
sc_features_columns = [
    col for col in sc_annotated_profiles.columns if col not in sc_metadata_columns
]

# %%
# find inf values and replace with NaN
sc_annotated_profiles[sc_features_columns] = sc_annotated_profiles[
    sc_features_columns
].replace([float("inf"), -float("inf")], np.nan)

# %%
# normalize the data
sc_normalized_profiles = normalize(
    sc_annotated_profiles,
    features=sc_features_columns,
    meta_features=sc_metadata_columns,
    method="standardize",
    samples="Metadata_treatment == 'DMSO'",
)
sc_normalized_profiles.to_parquet(sc_normalized_output_path, index=False)
sc_normalized_profiles.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # normalize the data
# ----> 2 sc_normalized_profiles = normalize(
#       3     sc_annotated_profiles,
#       4     features=sc_features_columns,
#       5     meta_features=sc_metadata_columns,
#       6     method="standardize",
#       7     samples="Metadata_treatment == 'DMSO'",
#       8 )
#       9 sc_normalized_profiles.to_parquet(sc_normalized_output_path, index=False)
#      10 sc_normalized_profiles.head()
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/pycytominer/normalize.py:165, in normalize(profiles, features, image_features, meta_features, samples, method, output_file, output_type, compression_options, float_format, mad_robustize_epsilon, spherize_center, spherize_method, spherize_epsilon)
#     162     fitted_scaler = scaler.fit(feature_df)
#     163 else:
#     164     # Subset to only the features measured in the sample query
# --> 165     fitted_scaler = scaler.fit(profiles.query(samples).loc[:, features])
#     167 fitted_scaled = fitted_scaler.transform(feature_df)
#     169 columns = fitted_scaler.columns if method == "spherize" else feature_df.columns
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:907, in StandardScaler.fit(self, X, y, sample_weight)
#     905 # Reset internal state before fitting
#     906 self._reset()
# --> 907 return self.partial_fit(X, y, sample_weight)
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:943, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     911 """Online computation of mean and std on X for later scaling.
#     912
#     913 All of X is processed as a single batch. This is intended for cases
#    (...)
#     940     Fitted scaler.
#     941 """
#     942 first_call = not hasattr(self, "n_samples_seen_")
# --> 943 X = validate_data(
#     944     self,
#     945     X,
#     946     accept_sparse=("csr", "csc"),
#     947     dtype=FLOAT_DTYPES,
#     948     ensure_all_finite="allow-nan",
#     949     reset=first_call,
#     950 )
#     951 n_features = X.shape[1]
#     953 if sample_weight is not None:
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/utils/validation.py:2954, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2952         out = X, y
#    2953 elif not no_val_X and no_val_y:
# -> 2954     out = check_array(X, input_name="X", **check_params)
#    2955 elif no_val_X and not no_val_y:
#    2956     out = _check_y(y, **check_params)
#
# File ~/miniforge3/envs/nf1_image_based_profiling_env/lib/python3.12/site-packages/sklearn/utils/validation.py:1128, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1126     n_samples = _num_samples(array)
#    1127     if n_samples < ensure_min_samples:
# -> 1128         raise ValueError(
#    1129             "Found array with %d sample(s) (shape=%s) while a"
#    1130             " minimum of %d is required%s."
#    1131             % (n_samples, array.shape, ensure_min_samples, context)
#    1132         )
#    1134 if ensure_min_features > 0 and array.ndim == 2:
#    1135     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 5960)) while a minimum of 1 is required by StandardScaler.

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_annotated_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                  19            uM              1
# 1              NF0014_T1                  15            uM              1
# 2              NF0014_T1                  47            uM              1
# 3              NF0014_T1                  40            uM             10
# 4              NF0014_T1                  37            uM             10
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2          Ketotifen               G6-1            G6
# 3       Mirdametinib               G8-1            G8
# 4       Mirdametinib               C9-2            C9
#
#    Metadata_single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                         1.0                        3268026.0
# 1                        11.0                        5570203.0
# 2                         9.0                        6134128.0
# 3                         8.0                        6416256.0
# 4                        13.0                       14239851.0
#
#    Area.Size.Shape_Organoid_CENTER.X  ...  \
# 0                         938.570068  ...
# 1                         950.582825  ...
# 2                         795.807983  ...
# 3                         769.689636  ...
# 4                         817.411133  ...
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.888459
# 1                                           0.853993
# 2                                           0.875041
# 3                                           0.943387
# 4                                           0.818021
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                 8.625683
# 1                                 7.177906
# 2                                13.244656
# 3                                 5.153550
# 4                                12.778783
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                 1.346913
# 1                                 1.556027
# 2                                 1.343332
# 3                                 0.835848
# 4                                 2.293907
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                702.361139
# 1                                297.955168
# 2                               1153.970316
# 3                                479.284825
# 4                                971.364210
#
#    Texture_Organoid_Mito_Variance_256.3                   Metadata_Target  \
# 0                            188.512030           PI3K and HDAC inhibitor
# 1                             85.399048           PI3K and HDAC inhibitor
# 2                            303.579081  histamine H1 receptor antagonist
# 3                            121.910734                  MEK1/2 inhibitor
# 4                            258.637076                  MEK1/2 inhibitor
#
#    Metadata_Class  Metadata_Therapeutic_Categories  Metadata_patient  \
# 0  Small Molecule                  Investigational            NF0014
# 1  Small Molecule                  Investigational            NF0014
# 2  Small Molecule             Anti-Allergic Agents            NF0014
# 3  Small Molecule                 Kinase Inhibitor            NF0014
# 4  Small Molecule                 Kinase Inhibitor            NF0014
#
#    Metadata_tumor
# 0              T1
# 1              T1
# 2              T1
# 3              T1
# 4              T1
#
# [5 rows x 464 columns]

# %%
organoid_metadata_columns = [
    x for x in organoid_annotated_profiles.columns if "Metadata" in x
]
organoid_metadata_columns += [
    "Area.Size.Shape_Organoid_CENTER.X",
    "Area.Size.Shape_Organoid_CENTER.Y",
    "Area.Size.Shape_Organoid_CENTER.Z",
]
organoid_features_columns = [
    col
    for col in organoid_annotated_profiles.columns
    if col not in organoid_metadata_columns
]
# normalize the data
organoid_normalized_profiles = normalize(
    organoid_annotated_profiles,
    features=organoid_features_columns,
    meta_features=organoid_metadata_columns,
    method="standardize",
    samples="Metadata_treatment == 'DMSO'",
)
organoid_normalized_profiles.to_parquet(organoid_normalized_output_path, index=False)
organoid_normalized_profiles.head()
# Out:
#   Metadata_patient_tumor  Metadata_object_id Metadata_unit  Metadata_dose  \
# 0              NF0014_T1                  19            uM              1
# 1              NF0014_T1                  15            uM              1
# 2              NF0014_T1                  47            uM              1
# 3              NF0014_T1                  40            uM             10
# 4              NF0014_T1                  37            uM             10
#
#   Metadata_treatment Metadata_image_set Metadata_Well  \
# 0       Fimepinostat               E5-2            E5
# 1       Fimepinostat               D5-2            D5
# 2          Ketotifen               G6-1            G6
# 3       Mirdametinib               G8-1            G8
# 4       Mirdametinib               C9-2            C9
#
#    Metadata_single_cell_count                   Metadata_Target  \
# 0                         1.0           PI3K and HDAC inhibitor
# 1                        11.0           PI3K and HDAC inhibitor
# 2                         9.0  histamine H1 receptor antagonist
# 3                         8.0                  MEK1/2 inhibitor
# 4                        13.0                  MEK1/2 inhibitor
#
#    Metadata_Class  ... Texture_Organoid_Mito_Difference.Entropy_256.3  \
# 0  Small Molecule  ...                                      -0.744079
# 1  Small Molecule  ...                                      -0.018758
# 2  Small Molecule  ...                                      -0.825789
# 3  Small Molecule  ...                                      -1.928917
# 4  Small Molecule  ...                                       1.306989
#
#   Texture_Organoid_Mito_Difference.Variance_256.3  \
# 0                                        0.929269
# 1                                        0.263903
# 2                                        0.752942
# 3                                        1.998597
# 4                                       -0.622370
#
#   Texture_Organoid_Mito_Entropy_256.3  \
# 0                           -0.876963
# 1                           -0.497285
# 2                           -0.748346
# 3                           -1.865807
# 4                            1.532605
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -0.149888
# 1                                           1.297494
# 2                                           0.050014
# 3                                          -0.723970
# 4                                           0.813374
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                          -0.453953
# 1                                          -1.614111
# 2                                          -0.465444
# 3                                          -1.483790
# 4                                           0.531467
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.3  \
# 0                                           0.924721
# 1                                           0.248123
# 2                                           0.661318
# 3                                           2.002970
# 4                                          -0.458024
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                -1.012954
# 1                                -1.166291
# 2                                -0.523751
# 3                                -1.380694
# 4                                -0.573092
#
#    Texture_Organoid_Mito_Sum.Entropy_256.3  \
# 0                                -0.840821
# 1                                -0.386110
# 2                                -0.848608
# 3                                -1.952115
# 4                                 1.218386
#
#    Texture_Organoid_Mito_Sum.Variance_256.3  \
# 0                                 -0.826647
# 1                                 -1.094204
# 2                                 -0.527859
# 3                                 -0.974235
# 4                                 -0.648673
#
#    Texture_Organoid_Mito_Variance_256.3
# 0                             -0.812516
# 1                             -1.082140
# 2                             -0.511635
# 3                             -0.986668
# 4                             -0.629151
#
# [5 rows x 464 columns]
