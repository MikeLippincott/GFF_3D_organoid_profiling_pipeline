# %% [markdown]
# This notebook performs profile normalization.
# All profiles are normalized to the DMSO control treated profiles.

# %%
import argparse
import pathlib

import numpy as np
import pandas as pd
from pycytominer import normalize

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "SARCO361"

# %%
# pathing
sc_annotated_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/sc_anno.parquet"
).resolve(strict=True)
organoid_annotated_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/organoid_anno.parquet"
).resolve(strict=True)


# output path
sc_normalized_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/sc_norm.parquet"
).resolve()
organoid_normalized_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/organoid_norm.parquet"
).resolve()

organoid_normalized_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_annotated_profiles = pd.read_parquet(sc_annotated_path)
organoid_annotated_profiles = pd.read_parquet(organoid_annotated_path)

# %% [markdown]
# ### Normalize the single-cell profiles

# %%
sc_annotated_profiles
# Out:
#        patient  object_id unit  dose   treatment image_set Well  \
# 0     SARCO361         63   uM     1   Nilotinib      F6-4   F6
# 1     SARCO361        127   uM     1   Nilotinib      F6-4   F6
# 2     SARCO361        191   uM     1   Nilotinib      F6-4   F6
# 3     SARCO361         19   uM     1  Everolimus      C5-4   C5
# 4     SARCO361         39   uM     1  Everolimus      C5-4   C5
# ...        ...        ...  ...   ...         ...       ...  ...
# 1498  SARCO361        102   uM     1  Trametinib     C10-1  C10
# 1499  SARCO361        153   uM     1  Trametinib     C10-1  C10
# 1500  SARCO361        204   uM     1  Trametinib     C10-1  C10
# 1501  SARCO361         85   uM     1  Trametinib     D10-3  D10
# 1502  SARCO361        170   uM     1  Trametinib     D10-3  D10
#
#       parent_organoid  Colocalization_Nuclei_AGP.BF_MEAN.CORRELATION.COEFF  \
# 0                  -1                                           0.139756
# 1                  12                                           0.128704
# 2                  -1                                          -0.016275
# 3                  45                                           0.168109
# 4                  45                                          -0.117636
# ...               ...                                                ...
# 1498               -1                                           0.109046
# 1499               -1                                           0.064015
# 1500               -1                                          -0.013406
# 1501               -1                                          -0.166372
# 1502               -1                                           0.117603
#
#       Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  ...  \
# 0                                              0.139756      ...
# 1                                              0.128704      ...
# 2                                             -0.016275      ...
# 3                                              0.168109      ...
# 4                                             -0.117636      ...
# ...                                                 ...      ...
# 1498                                           0.109046      ...
# 1499                                           0.064015      ...
# 1500                                          -0.013406      ...
# 1501                                          -0.166372      ...
# 1502                                           0.117603      ...
#
#       Area.Size.Shape_Cytoplasm_MAX.Y  Area.Size.Shape_Cytoplasm_MIN.Z  \
# 0                               974.0                              0.0
# 1                               510.0                              0.0
# 2                              1065.0                              0.0
# 3                               829.0                              0.0
# 4                               888.0                              3.0
# ...                               ...                              ...
# 1498                            754.0                              0.0
# 1499                           1217.0                              0.0
# 1500                            886.0                              0.0
# 1501                            765.0                              1.0
# 1502                           1184.0                              1.0
#
#       Area.Size.Shape_Cytoplasm_MAX.Z  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                                17.0                          0.373167
# 1                                17.0                          0.404097
# 2                                17.0                          0.272115
# 3                                30.0                          0.156531
# 4                                59.0                          0.114815
# ...                               ...                               ...
# 1498                             17.0                          0.225181
# 1499                             23.0                          0.434227
# 1500                             17.0                          0.371884
# 1501                              2.0                          0.253175
# 1502                             15.0                          0.324529
#
#       Area.Size.Shape_Cytoplasm_EULER.NUMBER  \
# 0                                      -11.0
# 1                                      -20.0
# 2                                      -14.0
# 3                                       -8.0
# 4                                      -53.0
# ...                                      ...
# 1498                                    -5.0
# 1499                                     2.0
# 1500                                     2.0
# 1501                                     3.0
# 1502                                     3.0
#
#       Area.Size.Shape_Cytoplasm_EQUIVALENT.DIAMETER  \
# 0                                         63.646595
# 1                                         72.924805
# 2                                         54.799179
# 3                                         66.073349
# 4                                         66.238449
# ...                                             ...
# 1498                                      50.823433
# 1499                                      86.278999
# 1500                                      60.581913
# 1501                                       8.477427
# 1502                                      55.797623
#
#       Area.Size.Shape_Cytoplasm_SURFACE.AREA                     Target  \
# 0                                1293.385132  tyrosine kinase inhibitor
# 1                                1622.490723  tyrosine kinase inhibitor
# 2                                1358.225220  tyrosine kinase inhibitor
# 3                                3067.721436             mTOR inhibitor
# 4                                5632.735352             mTOR inhibitor
# ...                                      ...                        ...
# 1498                             1607.640381           MEK1/2 inhibitor
# 1499                             2039.460693           MEK1/2 inhibitor
# 1500                             1073.544189           MEK1/2 inhibitor
# 1501                                     NaN           MEK1/2 inhibitor
# 1502                             1095.170532           MEK1/2 inhibitor
#
#                Class  Therapeutic Categories
# 0     Small Molecule         Investigational
# 1     Small Molecule         Investigational
# 2     Small Molecule         Investigational
# 3     Small Molecule        Kinase Inhibitor
# 4     Small Molecule        Kinase Inhibitor
# ...              ...                     ...
# 1498  Small Molecule        Kinase Inhibitor
# 1499  Small Molecule        Kinase Inhibitor
# 1500  Small Molecule        Kinase Inhibitor
# 1501  Small Molecule        Kinase Inhibitor
# 1502  Small Molecule        Kinase Inhibitor
#
# [1503 rows x 1933 columns]

# %%
sc_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "Target",
    "Class",
    "Therapeutic Categories",
    "image_set",
    "Well",
    "parent_organoid",
]
sc_features_columns = [
    col for col in sc_annotated_profiles.columns if col not in sc_metadata_columns
]

# %%
# find inf values and replace with NaN
sc_annotated_profiles[sc_features_columns] = sc_annotated_profiles[
    sc_features_columns
].replace([float("inf"), -float("inf")], np.nan)

# %%
# normalize the data
sc_normalized_profiles = normalize(
    sc_annotated_profiles,
    features=sc_features_columns,
    meta_features=sc_metadata_columns,
    method="standardize",
    samples="treatment == 'DMSO'",
)
sc_normalized_profiles.to_parquet(sc_normalized_output_path, index=False)
sc_normalized_profiles.head()
# Out:
#     patient  object_id unit  dose   treatment                     Target  \
# 0  SARCO361         63   uM     1   Nilotinib  tyrosine kinase inhibitor
# 1  SARCO361        127   uM     1   Nilotinib  tyrosine kinase inhibitor
# 2  SARCO361        191   uM     1   Nilotinib  tyrosine kinase inhibitor
# 3  SARCO361         19   uM     1  Everolimus             mTOR inhibitor
# 4  SARCO361         39   uM     1  Everolimus             mTOR inhibitor
#
#             Class Therapeutic Categories image_set Well  ...  \
# 0  Small Molecule        Investigational      F6-4   F6  ...
# 1  Small Molecule        Investigational      F6-4   F6  ...
# 2  Small Molecule        Investigational      F6-4   F6  ...
# 3  Small Molecule       Kinase Inhibitor      C5-4   C5  ...
# 4  Small Molecule       Kinase Inhibitor      C5-4   C5  ...
#
#    Area.Size.Shape_Cytoplasm_MIN.X  Area.Size.Shape_Cytoplasm_MAX.X  \
# 0                        -1.563725                        -1.596488
# 1                         0.263549                         0.292244
# 2                        -1.868271                        -1.957520
# 3                         0.544408                         0.690048
# 4                        -0.057916                        -0.078817
#
#    Area.Size.Shape_Cytoplasm_MIN.Y  Area.Size.Shape_Cytoplasm_MAX.Y  \
# 0                         0.795866                         0.709358
# 1                        -0.943569                        -0.941791
# 2                         1.121788                         1.033182
# 3                         0.243215                         0.193374
# 4                         0.466401                         0.403326
#
#    Area.Size.Shape_Cytoplasm_MIN.Z  Area.Size.Shape_Cytoplasm_MAX.Z  \
# 0                        -0.390267                        -0.776504
# 1                        -0.390267                        -0.776504
# 2                        -0.390267                        -0.776504
# 3                        -0.390267                         1.737238
# 4                         0.895252                         7.344817
#
#    Area.Size.Shape_Cytoplasm_EXTENT  Area.Size.Shape_Cytoplasm_EULER.NUMBER  \
# 0                          1.447654                                0.029134
# 1                          1.797869                               -0.810362
# 2                          0.303446                               -0.250698
# 3                         -1.005302                                0.308966
# 4                         -1.477648                               -3.888512
#
#    Area.Size.Shape_Cytoplasm_EQUIVALENT.DIAMETER  \
# 0                                       0.083745
# 1                                       0.584273
# 2                                      -0.393543
# 3                                       0.214660
# 4                                       0.223567
#
#    Area.Size.Shape_Cytoplasm_SURFACE.AREA
# 0                               -0.517441
# 1                               -0.246756
# 2                               -0.464110
# 3                                0.941926
# 4                                3.051615
#
# [5 rows x 1933 columns]

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_annotated_profiles.head()
# Out:
#     patient  object_id unit  dose    treatment image_set Well  \
# 0  SARCO361          3   uM     1  Selumetinib     G10-7  G10
# 1  SARCO361         12   uM     1    Nilotinib      F6-4   F6
# 2  SARCO361          3   uM    10  Binimetinib      C8-7   C8
# 3  SARCO361         45   uM     1   Everolimus      C5-4   C5
# 4  SARCO361          5   uM    10   Trametinib     F10-3  F10
#
#    single_cell_count  Colocalization_Organoid_AGP.BF_MEAN.CORRELATION.COEFF  \
# 0                NaN                                          -0.051867
# 1                1.0                                          -0.064466
# 2                NaN                                          -0.009716
# 3               12.0                                          -0.073847
# 4                NaN                                           0.055337
#
#    Colocalization_Organoid_AGP.BF_MEDIAN.CORRELATION.COEFF  ...  \
# 0                                          -0.051867        ...
# 1                                          -0.064466        ...
# 2                                          -0.009716        ...
# 3                                          -0.073847        ...
# 4                                           0.055337        ...
#
#    Area.Size.Shape_Organoid_MAX.Y  Area.Size.Shape_Organoid_MIN.Z  \
# 0                           949.0                             0.0
# 1                          1099.0                             2.0
# 2                           701.0                             0.0
# 3                          1505.0                             0.0
# 4                          1539.0                            15.0
#
#    Area.Size.Shape_Organoid_MAX.Z  Area.Size.Shape_Organoid_EXTENT  \
# 0                             4.0                         0.066092
# 1                            16.0                         0.000058
# 2                             4.0                         0.004887
# 3                            59.0                         0.178001
# 4                            21.0                         0.701991
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                                    7.0
# 1                                   77.0
# 2                                   56.0
# 3                                    4.0
# 4                                    1.0
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                      5.600968
# 1                                     10.818614
# 2                                      9.350074
# 3                                    271.688354
# 4                                     78.334473
#
#    Area.Size.Shape_Organoid_SURFACE.AREA                     Target  \
# 0                              20.176451           MEK1/2 inhibitor
# 1                             233.427032  tyrosine kinase inhibitor
# 2                             135.764496           MEK1/2 inhibitor
# 3                           31089.646484             mTOR inhibitor
# 4                             365.284912           MEK1/2 inhibitor
#
#             Class  Therapeutic Categories
# 0  Small Molecule        Kinase Inhibitor
# 1  Small Molecule         Investigational
# 2  Small Molecule        Kinase Inhibitor
# 3  Small Molecule        Kinase Inhibitor
# 4  Small Molecule        Kinase Inhibitor
#
# [5 rows x 651 columns]

# %%
organoid_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "Target",
    "Class",
    "Therapeutic Categories",
    "image_set",
    "Well",
    "single_cell_count",
]
organoid_features_columns = [
    col
    for col in organoid_annotated_profiles.columns
    if col not in organoid_metadata_columns
]
# normalize the data
organoid_normalized_profiles = normalize(
    organoid_annotated_profiles,
    features=organoid_features_columns,
    meta_features=organoid_metadata_columns,
    method="standardize",
    samples="treatment == 'DMSO'",
)
organoid_normalized_profiles.to_parquet(organoid_normalized_output_path, index=False)
organoid_normalized_profiles.head()
# Out:
#     patient  object_id unit  dose    treatment                     Target  \
# 0  SARCO361          3   uM     1  Selumetinib           MEK1/2 inhibitor
# 1  SARCO361         12   uM     1    Nilotinib  tyrosine kinase inhibitor
# 2  SARCO361          3   uM    10  Binimetinib           MEK1/2 inhibitor
# 3  SARCO361         45   uM     1   Everolimus             mTOR inhibitor
# 4  SARCO361          5   uM    10   Trametinib           MEK1/2 inhibitor
#
#             Class Therapeutic Categories image_set Well  ...  \
# 0  Small Molecule       Kinase Inhibitor     G10-7  G10  ...
# 1  Small Molecule        Investigational      F6-4   F6  ...
# 2  Small Molecule       Kinase Inhibitor      C8-7   C8  ...
# 3  Small Molecule       Kinase Inhibitor      C5-4   C5  ...
# 4  Small Molecule       Kinase Inhibitor     F10-3  F10  ...
#
#    Area.Size.Shape_Organoid_MIN.X  Area.Size.Shape_Organoid_MAX.X  \
# 0                        0.940022                       -2.848617
# 1                        0.420956                        0.918519
# 2                        1.146001                       -1.669552
# 3                       -0.161277                       -0.593228
# 4                        1.755697                        0.125953
#
#    Area.Size.Shape_Organoid_MIN.Y  Area.Size.Shape_Organoid_MAX.Y  \
# 0                        1.933864                       -1.101632
# 1                       -0.178544                       -0.569424
# 2                        0.830897                       -1.981549
# 3                        0.131061                        0.871084
# 4                        3.333536                        0.991718
#
#    Area.Size.Shape_Organoid_MIN.Z  Area.Size.Shape_Organoid_MAX.Z  \
# 0                       -0.500376                       -2.090429
# 1                        0.005380                       -0.549250
# 2                       -0.500376                       -2.090429
# 3                       -0.500376                        4.973309
# 4                        3.292798                        0.092908
#
#    Area.Size.Shape_Organoid_EXTENT  Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                        -0.848919                              -0.187277
# 1                        -1.243540                               3.975833
# 2                        -1.214684                               2.726900
# 3                        -0.180141                              -0.365696
# 4                         2.951274                              -0.544115
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                     -2.115236
# 1                                     -2.047617
# 2                                     -2.066649
# 3                                      1.333158
# 4                                     -1.172637
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -1.168251
# 1                              -1.145283
# 2                              -1.155802
# 3                               2.178146
# 4                              -1.131081
#
# [5 rows x 651 columns]
