# %% [markdown]
# This notebook performs profile feature selection.

# %%
import argparse
import pathlib

import pandas as pd
from pycytominer import feature_select

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "SARCO361"

# %%
# pathing
sc_normalized_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/sc_norm.parquet"
).resolve(strict=True)
organoid_normalized_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/organoid_norm.parquet"
).resolve(strict=True)


# output path
sc_fs_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/4.feature_selected_profiles/sc_fs.parquet"
).resolve()
organoid_fs_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/4.feature_selected_profiles/organoid_fs.parquet"
).resolve()

organoid_fs_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_normalized = pd.read_parquet(sc_normalized_path)
organoid_normalized = pd.read_parquet(organoid_normalized_path)

# %%
feature_select_ops = [
    "variance_threshold",
    "drop_na_columns",
    "correlation_threshold",
    "blocklist",
]

# %% [markdown]
# ### Feature select the single-cell profiles

# %%
sc_normalized.head()
# Out:
#     patient  object_id unit  dose   treatment          Target           Class  \
# 0  SARCO361         19   uM     1  Everolimus  mTOR inhibitor  Small Molecule
# 1  SARCO361         39   uM     1  Everolimus  mTOR inhibitor  Small Molecule
# 2  SARCO361         58   uM     1  Everolimus  mTOR inhibitor  Small Molecule
# 3  SARCO361         78   uM     1  Everolimus  mTOR inhibitor  Small Molecule
# 4  SARCO361         98   uM     1  Everolimus  mTOR inhibitor  Small Molecule
#
#   Therapeutic Categories image_set Well  ...  Area.Size.Shape_Cytoplasm_MIN.X  \
# 0       Kinase Inhibitor      C5-4   C5  ...                         0.399277
# 1       Kinase Inhibitor      C5-4   C5  ...                        -0.264814
# 2       Kinase Inhibitor      C5-4   C5  ...                         0.925326
# 3       Kinase Inhibitor      C5-4   C5  ...                        -0.656553
# 4       Kinase Inhibitor      C5-4   C5  ...                         0.738784
#
#    Area.Size.Shape_Cytoplasm_MAX.X  Area.Size.Shape_Cytoplasm_MIN.Y  \
# 0                         0.627346                         0.285328
# 1                        -0.259309                         0.505090
# 2                         0.700591                         0.846943
# 3                        -0.679506                         0.198121
# 4                         0.604216                         0.655087
#
#    Area.Size.Shape_Cytoplasm_MAX.Y  Area.Size.Shape_Cytoplasm_MIN.Z  \
# 0                         0.184579                           -0.375
# 1                         0.375293                            2.250
# 2                         0.456104                            5.750
# 3                         0.226601                            1.375
# 4                         0.430244                            4.875
#
#    Area.Size.Shape_Cytoplasm_MAX.Z  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                         2.139832                         -0.836526
# 1                         8.295097                         -1.300594
# 2                         2.564333                          0.529536
# 3                         5.323590                         -0.478178
# 4                         3.625585                         -0.710484
#
#    Area.Size.Shape_Cytoplasm_EULER.NUMBER  \
# 0                                0.127120
# 1                               -4.544532
# 2                                0.230934
# 3                               -1.430098
# 4                               -1.533912
#
#    Area.Size.Shape_Cytoplasm_EQUIVALENT.DIAMETER  \
# 0                                       0.358714
# 1                                       0.367507
# 2                                      -0.775283
# 3                                       0.950878
# 4                                      -0.398202
#
#    Area.Size.Shape_Cytoplasm_SURFACE.AREA
# 0                                1.609508
# 1                                4.539921
# 2                               -0.768679
# 3                                2.450180
# 4                                0.754258
#
# [5 rows x 1933 columns]

# %%
sc_blocklist = [
    x
    for x in sc_normalized.columns
    if "Area" in x and ("MAX" in x or "MIN" in x or "BBOX" in x or "CENTER" in x)
]
# write the blocklist to a file
# add "blocklist" the beginning of the list
sc_blocklist = ["blocklist"] + sc_blocklist
sc_blocklist_path = pathlib.Path(
    f"{root_dir}/4.processing_image_based_profiles/data/blocklist/sc_blocklist.txt"
).resolve()
sc_blocklist_path.parent.mkdir(parents=True, exist_ok=True)
with open(sc_blocklist_path, "w") as f:
    for item in sc_blocklist:
        f.write(f"{item}\n")

# %%
sc_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "image_set",
    "Target",
    "Class",
    "Therapeutic Categories",
    "Well",
    "parent_organoid",
]
sc_features_columns = [
    col for col in sc_normalized.columns if col not in sc_metadata_columns
]
sc_features_df = sc_normalized.drop(columns=sc_metadata_columns, errors="ignore")

# %%
# fs the data
sc_fs_profiles = feature_select(
    sc_features_df,
    operation=feature_select_ops,
    features=sc_features_columns,
    blocklist_file=sc_blocklist_path,
)
original_data_shape = sc_normalized.shape
sc_fs_profiles = pd.concat(
    [
        sc_normalized[sc_metadata_columns].reset_index(drop=True),
        sc_fs_profiles.reset_index(drop=True),
    ],
    axis=1,
)
print("The number features before feature selection:", original_data_shape[1])
print("The number features after feature selection:", sc_fs_profiles.shape[1])
sc_fs_profiles.to_parquet(sc_fs_output_path, index=False)
sc_fs_profiles.head()
# Out:
# The number features before feature selection: 1933
# The number features after feature selection: 226
#     patient  object_id unit  dose   treatment image_set          Target  \
# 0  SARCO361         19   uM     1  Everolimus      C5-4  mTOR inhibitor
# 1  SARCO361         39   uM     1  Everolimus      C5-4  mTOR inhibitor
# 2  SARCO361         58   uM     1  Everolimus      C5-4  mTOR inhibitor
# 3  SARCO361         78   uM     1  Everolimus      C5-4  mTOR inhibitor
# 4  SARCO361         98   uM     1  Everolimus      C5-4  mTOR inhibitor
#
#             Class Therapeutic Categories Well  ...  \
# 0  Small Molecule       Kinase Inhibitor   C5  ...
# 1  Small Molecule       Kinase Inhibitor   C5  ...
# 2  Small Molecule       Kinase Inhibitor   C5  ...
# 3  Small Molecule       Kinase Inhibitor   C5  ...
# 4  Small Molecule       Kinase Inhibitor   C5  ...
#
#    Granularity_Cytoplasm_Mito_GRANULARITY.1  \
# 0                                  0.506677
# 1                                  0.005694
# 2                                  0.331001
# 3                                  0.438188
# 4                                  0.002442
#
#    Texture_Cytoplasm_BF_Angular.Second.Moment_256.3  \
# 0                                          0.777007
# 1                                          0.757187
# 2                                          1.170315
# 3                                          0.471413
# 4                                          1.051855
#
#    Texture_Cytoplasm_BF_Information.Measure.of.Correlation.1_256.3  \
# 0                                          -0.712073
# 1                                          -0.436066
# 2                                          -1.135125
# 3                                          -1.288118
# 4                                           0.016516
#
#    Texture_Cytoplasm_BF_Sum.Variance_256.3  \
# 0                                -0.915372
# 1                                -0.608477
# 2                                -0.903262
# 3                                -0.705702
# 4                                -0.883929
#
#    Texture_Cytoplasm_DNA_Contrast_256.3  Texture_Cytoplasm_ER_Contrast_256.3  \
# 0                             -0.719147                            -0.463082
# 1                             -0.596133                             1.034804
# 2                             -1.096134                            -0.902594
# 3                             -0.295453                             0.036339
# 4                             -1.143580                            -0.443873
#
#    Texture_Cytoplasm_Mito_Correlation_256.3  \
# 0                                  0.344810
# 1                                  0.086968
# 2                                  0.293770
# 3                                  0.796643
# 4                                 -0.303698
#
#    Texture_Cytoplasm_Mito_Variance_256.3  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                              -0.914790                         -0.836526
# 1                               0.654268                         -1.300594
# 2                              -0.425628                          0.529536
# 3                               0.908627                         -0.478178
# 4                              -0.099879                         -0.710484
#
#    Area.Size.Shape_Cytoplasm_EULER.NUMBER
# 0                                0.127120
# 1                               -4.544532
# 2                                0.230934
# 3                               -1.430098
# 4                               -1.533912
#
# [5 rows x 226 columns]

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_normalized.head()
# Out:
#     patient  object_id unit  dose      treatment               Target  \
# 0  SARCO361         45   uM     1     Everolimus       mTOR inhibitor
# 1  SARCO361          4   nM    10  Staurosporine  Apoptosis induction
# 2  SARCO361         27   uM     1     Everolimus       mTOR inhibitor
# 3  SARCO361          5   uM     1      Onalespib      HSP90 inhibitor
# 4  SARCO361         28   uM     1      Onalespib      HSP90 inhibitor
#
#             Class Therapeutic Categories image_set Well  ...  \
# 0  Small Molecule       Kinase Inhibitor      C5-4   C5  ...
# 1  Small Molecule           Experimental     C11-2  C11  ...
# 2  Small Molecule       Kinase Inhibitor      C5-6   C5  ...
# 3  Small Molecule        Investigational      C3-3   C3  ...
# 4  Small Molecule        Investigational      C3-4   C3  ...
#
#    Area.Size.Shape_Organoid_MIN.X  Area.Size.Shape_Organoid_MAX.X  \
# 0                       -0.823303                       -0.661559
# 1                       -1.697752                       -0.692855
# 2                       -0.003168                       -1.282259
# 3                       -1.431616                       -2.033359
# 4                       -1.697752                        1.132735
#
#    Area.Size.Shape_Organoid_MIN.Y  Area.Size.Shape_Organoid_MAX.Y  \
# 0                       -0.199632                        0.854865
# 1                        0.042959                        0.987888
# 2                        0.240064                       -1.594314
# 3                        0.224902                        0.987888
# 4                       -2.024115                        0.987888
#
#    Area.Size.Shape_Organoid_MIN.Z  Area.Size.Shape_Organoid_MAX.Z  \
# 0                       -0.933257                        6.044266
# 1                       -0.933257                       -2.470265
# 2                        0.933257                        1.629324
# 3                       -0.933257                       -2.470265
# 4                       -0.933257                        0.683265
#
#    Area.Size.Shape_Organoid_EXTENT  Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                        -0.274677                               0.356235
# 1                         2.066893                               0.356235
# 2                         2.453575                              -0.926212
# 3                        -0.451312                              -0.071247
# 4                        -0.671532                               5.058541
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                      2.630958
# 1                                      1.062641
# 2                                      0.930080
# 3                                     -0.809746
# 4                                      1.741469
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                               5.281308
# 1                              -0.624914
# 2                              -0.401658
# 3                              -0.410041
# 4                               4.203173
#
# [5 rows x 651 columns]

# %%
organoid_blocklist = [
    x
    for x in organoid_normalized.columns
    if "Area" in x and ("MAX" in x or "MIN" in x or "BBOX" in x or "CENTER" in x)
]
# write the blocklist to a file
# add "blocklist" the beginning of the list
organoid_blocklist = ["blocklist"] + organoid_blocklist
organoid_blocklist_path = pathlib.Path(
    "../data/blocklist/organoid_blocklist.txt"
).resolve()
organoid_blocklist_path.parent.mkdir(parents=True, exist_ok=True)
with open(organoid_blocklist_path, "w") as f:
    for item in organoid_blocklist:
        f.write(f"{item}\n")

# %%
organoid_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "image_set",
    "Target",
    "Class",
    "Therapeutic Categories",
    "Well",
    "single_cell_count",
]
organoid_features_columns = [
    col for col in organoid_normalized.columns if col not in organoid_metadata_columns
]
organoid_features_df = organoid_normalized.drop(
    columns=organoid_metadata_columns, errors="ignore"
)

# %%
# normalize the data
organoid_fs_profiles = feature_select(
    organoid_features_df,
    operation=feature_select_ops,
    features=organoid_features_columns,
    blocklist_file=organoid_blocklist_path,
)
original_data_shape = organoid_normalized.shape
organoid_fs_profiles = pd.concat(
    [
        organoid_normalized[organoid_metadata_columns].reset_index(drop=True),
        organoid_fs_profiles.reset_index(drop=True),
    ],
    axis=1,
)

print("The number features before feature selection:", original_data_shape[1])
print("The number features after feature selection:", organoid_fs_profiles.shape[1])
organoid_fs_profiles.to_parquet(organoid_fs_output_path, index=False)
organoid_fs_profiles.head()
# Out:
# The number features before feature selection: 651
# The number features after feature selection: 151
#     patient  object_id unit  dose      treatment image_set  \
# 0  SARCO361         45   uM     1     Everolimus      C5-4
# 1  SARCO361          4   nM    10  Staurosporine     C11-2
# 2  SARCO361         27   uM     1     Everolimus      C5-6
# 3  SARCO361          5   uM     1      Onalespib      C3-3
# 4  SARCO361         28   uM     1      Onalespib      C3-4
#
#                 Target           Class Therapeutic Categories Well  ...  \
# 0       mTOR inhibitor  Small Molecule       Kinase Inhibitor   C5  ...
# 1  Apoptosis induction  Small Molecule           Experimental  C11  ...
# 2       mTOR inhibitor  Small Molecule       Kinase Inhibitor   C5  ...
# 3      HSP90 inhibitor  Small Molecule        Investigational   C3  ...
# 4      HSP90 inhibitor  Small Molecule        Investigational   C3  ...
#
#    Texture_Organoid_DNA_Sum.Variance_256.3  \
# 0                                 1.545744
# 1                                 0.701343
# 2                                 3.267712
# 3                                -1.263533
# 4                                -0.706097
#
#    Texture_Organoid_ER_Contrast_256.3  Texture_Organoid_ER_Sum.Average_256.3  \
# 0                           -0.675457                               0.390916
# 1                           -0.817489                               0.321596
# 2                           -1.384430                              -0.226361
# 3                           -0.932483                              -0.992392
# 4                           -1.540967                              -0.888877
#
#    Texture_Organoid_ER_Variance_256.3  Texture_Organoid_Mito_Contrast_256.3  \
# 0                           -0.513617                              6.944647
# 1                           -1.000235                              3.471792
# 2                           -0.824801                             -1.341468
# 3                           -1.107921                             12.843089
# 4                           -1.305535                              9.024406
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.3  \
# 0                                           1.094299
# 1                                           1.121110
# 2                                           1.439365
# 3                                          -1.438886
# 4                                           0.128921
#
#    Texture_Organoid_Mito_Sum.Average_256.3  \
# 0                                 4.284505
# 1                                 3.747953
# 2                                 1.430394
# 3                                -0.326730
# 4                                 3.239740
#
#    Texture_Organoid_Mito_Variance_256.3  Area.Size.Shape_Organoid_EXTENT  \
# 0                              8.313099                        -0.274677
# 1                              1.082282                         2.066893
# 2                              2.258404                         2.453575
# 3                              3.720659                        -0.451312
# 4                              3.342695                        -0.671532
#
#    Area.Size.Shape_Organoid_EULER.NUMBER
# 0                               0.356235
# 1                               0.356235
# 2                              -0.926212
# 3                              -0.071247
# 4                               5.058541
#
# [5 rows x 151 columns]
