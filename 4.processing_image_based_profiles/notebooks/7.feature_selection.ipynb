# %% [markdown]
# This notebook performs profile feature selection.

# %%
import argparse
import pathlib

import pandas as pd
from pycytominer import feature_select

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "NF0014"

# %%
# pathing
sc_normalized_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/2.sc_normalized_profiles.parquet"
).resolve(strict=True)
organoid_normalized_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/2.organoid_normalized_profiles.parquet"
).resolve(strict=True)


# output path
sc_fs_output_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/3.sc_fs_profiles.parquet"
).resolve()
organoid_fs_output_path = pathlib.Path(
    f"../../data/{patient}/image_based_profiles/3.organoid_fs_profiles.parquet"
).resolve()

# %%
# read in the data
sc_normalized = pd.read_parquet(sc_normalized_path)
organoid_normalized = pd.read_parquet(organoid_normalized_path)

# %%
feature_select_ops = [
    "variance_threshold",
    "drop_na_columns",
    "correlation_threshold",
    "blocklist",
]

# %% [markdown]
# ### Feature select the single-cell profiles

# %%
sc_normalized.head()
# Out:
#   patient  object_id unit  dose     treatment image_set Well  parent_organoid  \
# 0  NF0014         70   uM    10  Mirdametinib      G8-1   G8               40
# 1  NF0014        122   uM    10  Mirdametinib      G8-1   G8               40
# 2  NF0014        162   uM    10  Mirdametinib      G8-1   G8               40
# 3  NF0014        165   uM    10  Mirdametinib      G8-1   G8               40
# 4  NF0014        182   uM    10  Mirdametinib      G8-1   G8               40
#
#    Area.Size.Shape_Nuclei_VOLUME  Area.Size.Shape_Nuclei_CENTER.X  ...  \
# 0                      -0.688730                        -0.320369  ...
# 1                      -0.389751                        -0.493357  ...
# 2                      -0.331708                         0.049285  ...
# 3                      -0.472822                        -0.120799  ...
# 4                      -0.808064                        -0.351828  ...
#
#    Texture_Cytoplasm_Mito_Difference.Entropy_256.1  \
# 0                                         0.071470
# 1                                         0.125826
# 2                                        -0.002328
# 3                                        -0.220983
# 4                                        -0.108694
#
#    Texture_Cytoplasm_Mito_Difference.Variance_256.1  \
# 0                                          0.014529
# 1                                         -0.020770
# 2                                          0.054434
# 3                                          0.168983
# 4                                          0.111325
#
#    Texture_Cytoplasm_Mito_Entropy_256.1  \
# 0                              0.043398
# 1                              0.094458
# 2                             -0.009989
# 3                             -0.187017
# 4                             -0.100026
#
#    Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.1_256.1  \
# 0                                           0.553207
# 1                                           0.160591
# 2                                           0.284718
# 3                                           0.702270
# 4                                           0.171216
#
#    Texture_Cytoplasm_Mito_Information.Measure.of.Correlation.2_256.1  \
# 0                                           0.433568
# 1                                           0.654296
# 2                                           0.278696
# 3                                          -0.543070
# 4                                          -0.070353
#
#    Texture_Cytoplasm_Mito_Inverse.Difference.Moment_256.1  \
# 0                                           0.020056
# 1                                          -0.011324
# 2                                           0.058100
# 3                                           0.160654
# 4                                           0.109511
#
#    Texture_Cytoplasm_Mito_Sum.Average_256.1  \
# 0                                  0.042939
# 1                                  0.098997
# 2                                 -0.059797
# 3                                 -0.318593
# 4                                 -0.171670
#
#    Texture_Cytoplasm_Mito_Sum.Entropy_256.1  \
# 0                                  0.044455
# 1                                  0.100074
# 2                                 -0.012521
# 3                                 -0.203146
# 4                                 -0.106965
#
#    Texture_Cytoplasm_Mito_Sum.Variance_256.1  \
# 0                                   0.210545
# 1                                   0.240877
# 2                                  -0.003908
# 3                                  -0.489233
# 4                                  -0.206362
#
#    Texture_Cytoplasm_Mito_Variance_256.1
# 0                               0.217315
# 1                               0.241641
# 2                              -0.003837
# 3                              -0.489208
# 4                              -0.211112
#
# [5 rows x 1930 columns]

# %%
sc_blocklist = [
    x
    for x in sc_normalized.columns
    if "Area" in x and ("MAX" in x or "MIN" in x or "BBOX" in x or "CENTER" in x)
]
# write the blocklist to a file
# add "blocklist" the beginning of the list
sc_blocklist = ["blocklist"] + sc_blocklist
sc_blocklist_path = pathlib.Path("../data/blocklist/sc_blocklist.txt").resolve()
sc_blocklist_path.parent.mkdir(parents=True, exist_ok=True)
with open(sc_blocklist_path, "w") as f:
    for item in sc_blocklist:
        f.write(f"{item}\n")

# %%
sc_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "image_set",
    "Well",
    "parent_organoid",
]
sc_features_columns = [
    col for col in sc_normalized.columns if col not in sc_metadata_columns
]
sc_features_df = sc_normalized.drop(columns=sc_metadata_columns, errors="ignore")

# %%
# normalize the data
sc_fs_profiles = feature_select(
    sc_features_df,
    operation=feature_select_ops,
    features=sc_features_columns,
    blocklist_file=sc_blocklist_path,
)
sc_fs_profiles = pd.concat(
    [
        sc_normalized[sc_metadata_columns].reset_index(drop=True),
        sc_fs_profiles.reset_index(drop=True),
    ],
    axis=1,
)
sc_fs_profiles.to_parquet(sc_fs_output_path, index=False)
sc_fs_profiles.head()
# Out:
#   patient  object_id unit  dose     treatment image_set Well  parent_organoid  \
# 0  NF0014         70   uM    10  Mirdametinib      G8-1   G8               40
# 1  NF0014        122   uM    10  Mirdametinib      G8-1   G8               40
# 2  NF0014        162   uM    10  Mirdametinib      G8-1   G8               40
# 3  NF0014        165   uM    10  Mirdametinib      G8-1   G8               40
# 4  NF0014        182   uM    10  Mirdametinib      G8-1   G8               40
#
#    Area.Size.Shape_Nuclei_EXTENT  \
# 0                       0.590410
# 1                       0.242355
# 2                       0.427268
# 3                      -1.756083
# 4                       0.570591
#
#    Colocalization_Nuclei_AGP.BF_MIN.CORRELATION.COEFF  ...  \
# 0                                          -0.937207   ...
# 1                                           0.366156   ...
# 2                                          -0.703361   ...
# 3                                          -0.418309   ...
# 4                                           1.021355   ...
#
#    Texture_Cytoplasm_AGP_Information.Measure.of.Correlation.2_256.1  \
# 0                                           0.390195
# 1                                           0.550148
# 2                                           0.207164
# 3                                          -0.550337
# 4                                          -0.124153
#
#    Texture_Cytoplasm_BF_Correlation_256.1  \
# 0                                0.292325
# 1                                0.502795
# 2                                0.237268
# 3                               -0.142304
# 4                                0.383889
#
#    Texture_Cytoplasm_BF_Inverse.Difference.Moment_256.1  \
# 0                                           0.028686
# 1                                           0.003052
# 2                                           0.064626
# 3                                           0.154835
# 4                                           0.111983
#
#    Texture_Cytoplasm_BF_Sum.Average_256.1  \
# 0                               -0.034991
# 1                               -0.009418
# 2                               -0.070724
# 3                               -0.154227
# 4                               -0.101184
#
#    Texture_Cytoplasm_DNA_Contrast_256.1  \
# 0                             -0.743879
# 1                             -0.512470
# 2                              0.097954
# 3                             -0.878099
# 4                             -0.646486
#
#    Texture_Cytoplasm_DNA_Sum.Variance_256.1  \
# 0                                 -0.644247
# 1                                 -0.388735
# 2                                  0.042600
# 3                                 -0.726517
# 4                                 -0.469616
#
#    Texture_Cytoplasm_ER_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -0.132689
# 1                                          -0.743222
# 2                                          -0.598672
# 3                                          -0.326628
# 4                                          -1.041207
#
#    Texture_Cytoplasm_ER_Sum.Variance_256.1  \
# 0                                -0.616014
# 1                                -0.410225
# 2                                -0.553485
# 3                                -0.580438
# 4                                -0.500639
#
#    Texture_Cytoplasm_Mito_Contrast_256.1  \
# 0                               0.387111
# 1                               0.233132
# 2                              -0.001264
# 3                              -0.426149
# 4                              -0.322758
#
#    Texture_Cytoplasm_Mito_Sum.Variance_256.1
# 0                                   0.210545
# 1                                   0.240877
# 2                                  -0.003908
# 3                                  -0.489233
# 4                                  -0.206362
#
# [5 rows x 294 columns]

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_normalized.head()
# Out:
#   patient  object_id unit  dose     treatment image_set Well  \
# 0  NF0014         40   uM    10  Mirdametinib      G8-1   G8
# 1  NF0014         24   uM     1  Fimepinostat      D5-1   D5
# 2  NF0014         85   uM     1  Mirdametinib      F8-1   F8
# 3  NF0014         18   nM    10        STAURO     G11-1  G11
# 4  NF0014         24   uM     1   Binimetinib      G7-1   G7
#
#    single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                  8                        -1.718171
# 1                  5                        -2.085979
# 2                  9                         0.130074
# 3                  1                        -2.223655
# 4                  6                        -1.728123
#
#    Area.Size.Shape_Organoid_CENTER.X  ...  \
# 0                          -0.204121  ...
# 1                           1.325346  ...
# 2                          -2.027178  ...
# 3                           2.247724  ...
# 4                           1.564666  ...
#
#    Texture_Organoid_Mito_Difference.Entropy_256.1  \
# 0                                       -2.133984
# 1                                        0.595326
# 2                                        2.021954
# 3                                       -2.453815
# 4                                       -1.087216
#
#    Texture_Organoid_Mito_Difference.Variance_256.1  \
# 0                                         2.118421
# 1                                        -0.249176
# 2                                        -2.551488
# 3                                         2.302870
# 4                                         1.297326
#
#    Texture_Organoid_Mito_Entropy_256.1  \
# 0                            -1.889329
# 1                            -0.130507
# 2                             2.543025
# 3                            -2.233725
# 4                            -0.942457
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -1.389515
# 1                                           3.504391
# 2                                           1.116702
# 3                                          -1.756270
# 4                                          -1.000208
#
#    Texture_Organoid_Mito_Information.Measure.of.Correlation.2_256.1  \
# 0                                          -2.146901
# 1                                          -4.467319
# 2                                           1.484100
# 3                                          -3.008386
# 4                                          -0.322736
#
#    Texture_Organoid_Mito_Inverse.Difference.Moment_256.1  \
# 0                                           2.142268
# 1                                          -0.035009
# 2                                          -1.863943
# 3                                           2.194833
# 4                                           1.261960
#
#    Texture_Organoid_Mito_Sum.Average_256.1  \
# 0                                -1.376009
# 1                                -1.498039
# 2                                -0.923582
# 3                                -1.196517
# 4                                -0.360881
#
#    Texture_Organoid_Mito_Sum.Entropy_256.1  \
# 0                                -1.968139
# 1                                -0.153214
# 2                                 2.403406
# 3                                -2.305849
# 4                                -0.943562
#
#    Texture_Organoid_Mito_Sum.Variance_256.1  \
# 0                                 -0.980562
# 1                                 -1.127113
# 2                                 -1.189460
# 3                                 -0.726536
# 4                                  0.087396
#
#    Texture_Organoid_Mito_Variance_256.1
# 0                             -0.987831
# 1                             -1.093515
# 2                             -1.193731
# 3                             -0.730073
# 4                              0.078821
#
# [5 rows x 648 columns]

# %%
organoid_blocklist = [
    x
    for x in organoid_normalized.columns
    if "Area" in x and ("MAX" in x or "MIN" in x or "BBOX" in x or "CENTER" in x)
]
# write the blocklist to a file
# add "blocklist" the beginning of the list
organoid_blocklist = ["blocklist"] + organoid_blocklist
organoid_blocklist_path = pathlib.Path(
    "../data/blocklist/organoid_blocklist.txt"
).resolve()
organoid_blocklist_path.parent.mkdir(parents=True, exist_ok=True)
with open(organoid_blocklist_path, "w") as f:
    for item in organoid_blocklist:
        f.write(f"{item}\n")

# %%
organoid_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "image_set",
    "Well",
    "single_cell_count",
]
organoid_features_columns = [
    col for col in organoid_normalized.columns if col not in organoid_metadata_columns
]
organoid_features_df = organoid_normalized.drop(
    columns=organoid_metadata_columns, errors="ignore"
)

# %%
# normalize the data
organoid_fs_profiles = feature_select(
    organoid_features_df,
    operation=feature_select_ops,
    features=organoid_features_columns,
    blocklist_file=organoid_blocklist_path,
)
organoid_fs_profiles = pd.concat(
    [
        organoid_normalized[organoid_metadata_columns].reset_index(drop=True),
        organoid_fs_profiles.reset_index(drop=True),
    ],
    axis=1,
)
organoid_fs_profiles.to_parquet(organoid_fs_output_path, index=False)
organoid_fs_profiles.head()
# Out:
#   patient  object_id unit  dose     treatment image_set Well  \
# 0  NF0014         40   uM    10  Mirdametinib      G8-1   G8
# 1  NF0014         24   uM     1  Fimepinostat      D5-1   D5
# 2  NF0014         85   uM     1  Mirdametinib      F8-1   F8
# 3  NF0014         18   nM    10        STAURO     G11-1  G11
# 4  NF0014         24   uM     1   Binimetinib      G7-1   G7
#
#    single_cell_count  Area.Size.Shape_Organoid_VOLUME  \
# 0                  8                        -1.718171
# 1                  5                        -2.085979
# 2                  9                         0.130074
# 3                  1                        -2.223655
# 4                  6                        -1.728123
#
#    Area.Size.Shape_Organoid_EXTENT  ...  Texture_Organoid_BF_Variance_256.1  \
# 0                        -1.664739  ...                           -1.334719
# 1                        -2.484067  ...                           -0.427715
# 2                        -0.663134  ...                            0.068257
# 3                         0.265362  ...                           -1.677969
# 4                        -0.369563  ...                           -0.549648
#
#    Texture_Organoid_DNA_Contrast_256.1  Texture_Organoid_DNA_Variance_256.1  \
# 0                            -1.068404                            -1.112068
# 1                            -0.455481                            -1.543011
# 2                            -0.455344                            -1.153488
# 3                            -1.018121                            -1.357958
# 4                            -0.699480                            -0.593020
#
#    Texture_Organoid_ER_Contrast_256.1  \
# 0                           -0.635342
# 1                            0.074815
# 2                            0.648688
# 3                           -0.786237
# 4                           -0.760946
#
#    Texture_Organoid_ER_Information.Measure.of.Correlation.1_256.1  \
# 0                                          -2.238332
# 1                                           5.133408
# 2                                           1.518773
# 3                                          -2.838483
# 4                                          -0.497278
#
#    Texture_Organoid_ER_Sum.Average_256.1  Texture_Organoid_ER_Variance_256.1  \
# 0                              -1.169085                           -0.882218
# 1                              -1.179782                           -0.995430
# 2                               0.786162                           -0.364094
# 3                              -1.520782                           -1.059963
# 4                              -1.270120                           -1.007393
#
#    Texture_Organoid_Mito_Contrast_256.1  \
# 0                             -0.972143
# 1                              1.584246
# 2                             -0.886440
# 3                             -0.601197
# 4                             -0.507220
#
#    Texture_Organoid_Mito_Sum.Average_256.1  \
# 0                                -1.376009
# 1                                -1.498039
# 2                                -0.923582
# 3                                -1.196517
# 4                                -0.360881
#
#    Texture_Organoid_Mito_Variance_256.1
# 0                             -0.987831
# 1                             -1.093515
# 2                             -1.193731
# 3                             -0.730073
# 4                              0.078821
#
# [5 rows x 156 columns]
