# %% [markdown]
# This notebook performs profile normalization.
# All profiles are normalized to the DMSO control treated profiles.

# %%
import argparse
import pathlib

import numpy as np
import pandas as pd
from pycytominer import normalize

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")
try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--patient",
        type=str,
        required=True,
        help="Patient ID to process, e.g. 'P01'",
    )
    args = argparser.parse_args()
    patient = args.patient

else:
    patient = "NF0014"

# %%
# pathing
sc_annotated_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/sc_anno.parquet"
).resolve(strict=True)
organoid_annotated_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/2.annotated_profiles/organoid_anno.parquet"
).resolve(strict=True)


# output path
sc_normalized_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/sc_norm.parquet"
).resolve()
organoid_normalized_output_path = pathlib.Path(
    f"{root_dir}/data/{patient}/image_based_profiles/3.normalized_profiles/organoid_norm.parquet"
).resolve()

organoid_normalized_output_path.parent.mkdir(parents=True, exist_ok=True)

# %%
# read in the data
sc_annotated_profiles = pd.read_parquet(sc_annotated_path)
organoid_annotated_profiles = pd.read_parquet(organoid_annotated_path)

# %% [markdown]
# ### Normalize the single-cell profiles

# %%
sc_annotated_profiles
# Out:
#      patient  object_id unit  dose     treatment image_set Well  \
# 0     NF0014         25   uM    10  Mirdametinib      G8-1   G8
# 1     NF0014         51   uM    10  Mirdametinib      G8-1   G8
# 2     NF0014         76   uM    10  Mirdametinib      G8-1   G8
# 3     NF0014        102   uM    10  Mirdametinib      G8-1   G8
# 4     NF0014        127   uM    10  Mirdametinib      G8-1   G8
# ...      ...        ...  ...   ...           ...       ...  ...
# 1396  NF0014         36   uM     1    Trametinib     C10-1  C10
# 1397  NF0014         72   uM     1    Trametinib     C10-1  C10
# 1398  NF0014        145   uM     1    Trametinib     C10-1  C10
# 1399  NF0014        182   uM     1    Trametinib     C10-1  C10
# 1400  NF0014        218   uM     1    Trametinib     C10-1  C10
#
#       parent_organoid  Colocalization_Nuclei_AGP.BF_MEAN.CORRELATION.COEFF  \
# 0                  40                                          -0.039767
# 1                  40                                           0.028712
# 2                  40                                          -0.027481
# 3                  40                                          -0.012504
# 4                  40                                           0.063136
# ...               ...                                                ...
# 1396               -1                                          -0.046983
# 1397               44                                           0.123355
# 1398               44                                           0.018397
# 1399               44                                           0.029158
# 1400               44                                          -0.014287
#
#       Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  ...  \
# 0                                             -0.039767      ...
# 1                                              0.028712      ...
# 2                                             -0.027481      ...
# 3                                             -0.012504      ...
# 4                                              0.063136      ...
# ...                                                 ...      ...
# 1396                                          -0.046983      ...
# 1397                                           0.123355      ...
# 1398                                           0.018397      ...
# 1399                                           0.029158      ...
# 1400                                          -0.014287      ...
#
#       Area.Size.Shape_Cytoplasm_MAX.Y  Area.Size.Shape_Cytoplasm_MIN.Z  \
# 0                               909.0                              0.0
# 1                               916.0                              0.0
# 2                               762.0                              0.0
# 3                               872.0                              0.0
# 4                               786.0                              0.0
# ...                               ...                              ...
# 1396                           1158.0                              0.0
# 1397                           1117.0                              0.0
# 1398                           1040.0                              0.0
# 1399                           1142.0                              0.0
# 1400                           1008.0                              0.0
#
#       Area.Size.Shape_Cytoplasm_MAX.Z  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                                29.0                          0.100018
# 1                                41.0                          0.131350
# 2                                41.0                          0.162104
# 3                                39.0                          0.159934
# 4                                41.0                          0.211394
# ...                               ...                               ...
# 1396                             18.0                          0.102583
# 1397                             31.0                          0.109106
# 1398                             33.0                          0.140407
# 1399                             45.0                          0.243124
# 1400                             45.0                          0.334455
#
#       Area.Size.Shape_Cytoplasm_EULER.NUMBER  \
# 0                                      -44.0
# 1                                      -54.0
# 2                                      -36.0
# 3                                      -37.0
# 4                                      -55.0
# ...                                      ...
# 1396                                    -7.0
# 1397                                   -25.0
# 1398                                   -29.0
# 1399                                   -46.0
# 1400                                   -21.0
#
#       Area.Size.Shape_Cytoplasm_EQUIVALENT.DIAMETER  \
# 0                                         86.478996
# 1                                         90.847000
# 2                                         81.312607
# 3                                         62.487492
# 4                                         73.653473
# ...                                             ...
# 1396                                      48.076462
# 1397                                      84.423706
# 1398                                      69.789490
# 1399                                     148.760895
# 1400                                     156.430557
#
#       Area.Size.Shape_Cytoplasm_SURFACE.AREA            Target  \
# 0                                8537.206055  MEK1/2 inhibitor
# 1                                7764.473145  MEK1/2 inhibitor
# 2                                3883.599609  MEK1/2 inhibitor
# 3                                1958.485352  MEK1/2 inhibitor
# 4                                3029.156738  MEK1/2 inhibitor
# ...                                      ...               ...
# 1396                             1402.699829  MEK1/2 inhibitor
# 1397                             5054.512695  MEK1/2 inhibitor
# 1398                             1238.590454  MEK1/2 inhibitor
# 1399                            12245.774414  MEK1/2 inhibitor
# 1400                             9464.797852  MEK1/2 inhibitor
#
#                Class  Therapeutic Categories
# 0     Small Molecule        Kinase Inhibitor
# 1     Small Molecule        Kinase Inhibitor
# 2     Small Molecule        Kinase Inhibitor
# 3     Small Molecule        Kinase Inhibitor
# 4     Small Molecule        Kinase Inhibitor
# ...              ...                     ...
# 1396  Small Molecule        Kinase Inhibitor
# 1397  Small Molecule        Kinase Inhibitor
# 1398  Small Molecule        Kinase Inhibitor
# 1399  Small Molecule        Kinase Inhibitor
# 1400  Small Molecule        Kinase Inhibitor
#
# [1401 rows x 1933 columns]

# %%
sc_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "Target",
    "Class",
    "Therapeutic Categories",
    "image_set",
    "Well",
    "parent_organoid",
]
sc_features_columns = [
    col for col in sc_annotated_profiles.columns if col not in sc_metadata_columns
]

# %%
# find inf values and replace with NaN
sc_annotated_profiles[sc_features_columns] = sc_annotated_profiles[
    sc_features_columns
].replace([float("inf"), -float("inf")], np.nan)

# %%
# normalize the data
sc_normalized_profiles = normalize(
    sc_annotated_profiles,
    features=sc_features_columns,
    meta_features=sc_metadata_columns,
    method="standardize",
    samples="treatment == 'DMSO'",
)
sc_normalized_profiles.to_parquet(sc_normalized_output_path, index=False)
sc_normalized_profiles.head()
# Out:
#   patient  object_id unit  dose     treatment            Target  \
# 0  NF0014         25   uM    10  Mirdametinib  MEK1/2 inhibitor
# 1  NF0014         51   uM    10  Mirdametinib  MEK1/2 inhibitor
# 2  NF0014         76   uM    10  Mirdametinib  MEK1/2 inhibitor
# 3  NF0014        102   uM    10  Mirdametinib  MEK1/2 inhibitor
# 4  NF0014        127   uM    10  Mirdametinib  MEK1/2 inhibitor
#
#             Class Therapeutic Categories image_set Well  ...  \
# 0  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
# 1  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
# 2  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
# 3  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
# 4  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
#
#    Area.Size.Shape_Cytoplasm_MIN.X  Area.Size.Shape_Cytoplasm_MAX.X  \
# 0                        -0.368271                         0.087323
# 1                        -0.314821                         0.005405
# 2                         0.053986                        -0.184031
# 3                         0.134162                        -0.245470
# 4                        -0.175850                        -0.568023
#
#    Area.Size.Shape_Cytoplasm_MIN.Y  Area.Size.Shape_Cytoplasm_MAX.Y  \
# 0                        -0.472441                         0.024274
# 1                        -0.035168                         0.048724
# 2                        -0.500205                        -0.489164
# 3                         0.232054                        -0.104958
# 4                        -0.167044                        -0.405337
#
#    Area.Size.Shape_Cytoplasm_MIN.Z  Area.Size.Shape_Cytoplasm_MAX.Z  \
# 0                        -0.733567                        -1.092632
# 1                        -0.733567                        -0.102714
# 2                        -0.733567                        -0.102714
# 3                        -0.733567                        -0.267701
# 4                        -0.733567                        -0.102714
#
#    Area.Size.Shape_Cytoplasm_EXTENT  Area.Size.Shape_Cytoplasm_EULER.NUMBER  \
# 0                         -0.965185                               -0.394215
# 1                         -0.529325                               -0.810092
# 2                         -0.101508                               -0.061513
# 3                         -0.131695                               -0.103101
# 4                          0.584169                               -0.851680
#
#    Area.Size.Shape_Cytoplasm_EQUIVALENT.DIAMETER  \
# 0                                       0.160842
# 1                                       0.301193
# 2                                      -0.005162
# 3                                      -0.610043
# 4                                      -0.251262
#
#    Area.Size.Shape_Cytoplasm_SURFACE.AREA
# 0                                0.942953
# 1                                0.751769
# 2                               -0.208408
# 3                               -0.684706
# 4                               -0.419808
#
# [5 rows x 1933 columns]

# %% [markdown]
# ### Normalize the organoid profiles

# %%
organoid_annotated_profiles.head()
# Out:
#   patient  object_id unit  dose      treatment image_set Well  \
# 0  NF0014         40   uM    10   Mirdametinib      G8-1   G8
# 1  NF0014         24   uM     1   Fimepinostat      D5-1   D5
# 2  NF0014         85   uM     1   Mirdametinib      F8-1   F8
# 3  NF0014         18   nM    10  Staurosporine     G11-1  G11
# 4  NF0014         24   uM     1    Binimetinib      G7-1   G7
#
#    single_cell_count  Colocalization_Organoid_AGP.BF_MEAN.CORRELATION.COEFF  \
# 0                8.0                                          -0.047442
# 1                5.0                                           0.034538
# 2                9.0                                           0.018870
# 3                1.0                                           0.005859
# 4                7.0                                          -0.022475
#
#    Colocalization_Organoid_AGP.BF_MEDIAN.CORRELATION.COEFF  ...  \
# 0                                          -0.047442        ...
# 1                                           0.034538        ...
# 2                                           0.018870        ...
# 3                                           0.005859        ...
# 4                                          -0.022475        ...
#
#    Area.Size.Shape_Organoid_MAX.Y  Area.Size.Shape_Organoid_MIN.Z  \
# 0                          1162.0                             0.0
# 1                          1518.0                             0.0
# 2                          1537.0                             0.0
# 3                          1085.0                             0.0
# 4                          1227.0                             0.0
#
#    Area.Size.Shape_Organoid_MAX.Z  Area.Size.Shape_Organoid_EXTENT  \
# 0                            41.0                         0.267881
# 1                            11.0                         0.144968
# 2                            23.0                         0.418138
# 3                            19.0                         0.557427
# 4                            25.0                         0.462178
#
#    Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                                    1.0
# 1                                    5.0
# 2                                   14.0
# 3                                    1.0
# 4                                    1.0
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                    230.547821
# 1                                    192.377014
# 2                                    336.359833
# 3                                    173.222839
# 4                                    229.673218
#
#    Area.Size.Shape_Organoid_SURFACE.AREA                   Target  \
# 0                            9698.893555         MEK1/2 inhibitor
# 1                           33464.886719  PI3K and HDAC inhibitor
# 2                           24271.376953         MEK1/2 inhibitor
# 3                            3804.474365      Apoptosis induction
# 4                            6281.933594         MEK1/2 inhibitor
#
#             Class  Therapeutic Categories
# 0  Small Molecule        Kinase Inhibitor
# 1  Small Molecule         Investigational
# 2  Small Molecule        Kinase Inhibitor
# 3  Small Molecule            Experimental
# 4  Small Molecule        Kinase Inhibitor
#
# [5 rows x 651 columns]

# %%
organoid_metadata_columns = [
    "patient",
    "object_id",
    "unit",
    "dose",
    "treatment",
    "Target",
    "Class",
    "Therapeutic Categories",
    "image_set",
    "Well",
    "single_cell_count",
]
organoid_features_columns = [
    col
    for col in organoid_annotated_profiles.columns
    if col not in organoid_metadata_columns
]
# normalize the data
organoid_normalized_profiles = normalize(
    organoid_annotated_profiles,
    features=organoid_features_columns,
    meta_features=organoid_metadata_columns,
    method="standardize",
    samples="treatment == 'DMSO'",
)
organoid_normalized_profiles.to_parquet(organoid_normalized_output_path, index=False)
organoid_normalized_profiles.head()
# Out:
#   patient  object_id unit  dose      treatment                   Target  \
# 0  NF0014         40   uM    10   Mirdametinib         MEK1/2 inhibitor
# 1  NF0014         24   uM     1   Fimepinostat  PI3K and HDAC inhibitor
# 2  NF0014         85   uM     1   Mirdametinib         MEK1/2 inhibitor
# 3  NF0014         18   nM    10  Staurosporine      Apoptosis induction
# 4  NF0014         24   uM     1    Binimetinib         MEK1/2 inhibitor
#
#             Class Therapeutic Categories image_set Well  ...  \
# 0  Small Molecule       Kinase Inhibitor      G8-1   G8  ...
# 1  Small Molecule        Investigational      D5-1   D5  ...
# 2  Small Molecule       Kinase Inhibitor      F8-1   F8  ...
# 3  Small Molecule           Experimental     G11-1  G11  ...
# 4  Small Molecule       Kinase Inhibitor      G7-1   G7  ...
#
#    Area.Size.Shape_Organoid_MIN.X  Area.Size.Shape_Organoid_MAX.X  \
# 0                        0.739470                       -0.591772
# 1                       -1.476846                        2.007526
# 2                       -0.973600                        1.404696
# 3                        2.452539                       -0.021353
# 4                        1.425714                        0.717600
#
#    Area.Size.Shape_Organoid_MIN.Y  Area.Size.Shape_Organoid_MAX.Y  \
# 0                        0.300786                       -0.758819
# 1                       -1.177400                        1.090707
# 2                       -1.177400                        1.189417
# 3                        1.140360                       -1.158857
# 4                        1.118031                       -0.421125
#
#    Area.Size.Shape_Organoid_MIN.Z  Area.Size.Shape_Organoid_MAX.Z  \
# 0                       -0.357143                       -0.229918
# 1                       -0.357143                       -2.484878
# 2                       -0.357143                       -1.582894
# 3                       -0.357143                       -1.883555
# 4                       -0.357143                       -1.432563
#
#    Area.Size.Shape_Organoid_EXTENT  Area.Size.Shape_Organoid_EULER.NUMBER  \
# 0                        -1.664740                              -0.408830
# 1                        -2.484073                              -0.326823
# 2                        -0.663129                              -0.142307
# 3                         0.265372                              -0.408830
# 4                        -0.369556                              -0.408830
#
#    Area.Size.Shape_Organoid_EQUIVALENT.DIAMETER  \
# 0                                     -2.100216
# 1                                     -2.949785
# 2                                      0.254844
# 3                                     -3.376100
# 4                                     -2.119682
#
#    Area.Size.Shape_Organoid_SURFACE.AREA
# 0                              -1.007454
# 1                               1.041542
# 2                               0.248920
# 3                              -1.515644
# 4                              -1.302049
#
# [5 rows x 651 columns]
