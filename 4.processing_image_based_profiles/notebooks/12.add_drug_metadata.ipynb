# %%
import argparse
import pathlib

import duckdb
import pandas as pd

# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False

# %%
drug_information = pd.read_csv(
    pathlib.Path(
        f"{root_dir}/4.processing_image_based_profiles/data/drugs/drug_information.csv"
    )
)
drug_information.head()
# Out:
#       Treatment             Pathway  \
# 0       ARV-825               C-MYC
# 1   Binimetinib              MEK1/2
# 2  Cabozantinib              MEK1/2
# 3    Copanlisib  mTOR;NF-kB; MEK1/2
# 4          DMSO             Control
#
#                                             Function           Class  \
# 0                                      Degrades BRD4          PROTAC
# 1                                    Inhibits MEK1/2  Small Molecule
# 2  Inhibits FLT3; c-KIT; c-RET; AXL; c-MET; VEGFR...  Small Molecule
# 3                                      Inhibits PI3K  Small Molecule
# 4                                            Control         Control
#
#   Therapeutic Categories
# 0                 PROTAC
# 1       Kinase Inhibitor
# 2       Kinase Inhibitor
# 3       Kinase Inhibitor
# 4                Control

# %%
profiles_dir = pathlib.Path(f"{root_dir}/data/all_patient_profiles/").resolve(
    strict=True
)
# get a list of all profiles
profiles = [f for f in profiles_dir.glob("*.parquet") if f.is_file()]
for profile in profiles:
    df = pd.read_parquet(profile)
    df["treatment"] = df["treatment"].replace("STAURO", "Staurosporine")
    df["treatment"] = df["treatment"].replace("Staurosporine ", "Staurosporine")
    df = df.merge(
        drug_information, how="left", left_on="treatment", right_on="Treatment"
    )
    df.to_parquet(profile, index=False)

# %%
df
# Out:
#         patient  object_id unit  dose     treatment image_set Well  \
# 0        NF0014         25   uM    10  Mirdametinib      G8-1   G8
# 1        NF0014         51   uM    10  Mirdametinib      G8-1   G8
# 2        NF0014         76   uM    10  Mirdametinib      G8-1   G8
# 3        NF0014        102   uM    10  Mirdametinib      G8-1   G8
# 4        NF0014        127   uM    10  Mirdametinib      G8-1   G8
# ...         ...        ...  ...   ...           ...       ...  ...
# 11227  SARCO361        102   uM     1    Trametinib     C10-1  C10
# 11228  SARCO361        153   uM     1    Trametinib     C10-1  C10
# 11229  SARCO361        204   uM     1    Trametinib     C10-1  C10
# 11230  SARCO361         85   uM     1    Trametinib     D10-3  D10
# 11231  SARCO361        170   uM     1    Trametinib     D10-3  D10
#
#        parent_organoid  Colocalization_Nuclei_AGP.BF_MEDIAN.CORRELATION.COEFF  \
# 0                   40                                          -0.962054
# 1                   40                                           0.424670
# 2                   40                                          -0.713252
# 3                   40                                          -0.409968
# 4                   40                                           1.121776
# ...                ...                                                ...
# 11227               -1                                           0.839536
# 11228               -1                                           0.416243
# 11229               -1                                          -0.311504
# 11230               -1                                          -1.749370
# 11231               -1                                           0.919971
#
#        Colocalization_Nuclei_AGP.BF_MEAN.OVERLAP.COEFF  ...  \
# 0                                            -0.265852  ...
# 1                                            -0.271004  ...
# 2                                            -0.271616  ...
# 3                                            -0.153681  ...
# 4                                            -0.271732  ...
# ...                                                ...  ...
# 11227                                        -0.153940  ...
# 11228                                        -0.151759  ...
# 11229                                        -0.182692  ...
# 11230                                         0.151984  ...
# 11231                                        -0.172551  ...
#
#        Texture_Cytoplasm_Mito_Sum.Average_256.3  \
# 0                                      0.009685
# 1                                      0.078748
# 2                                     -0.067183
# 3                                     -0.320329
# 4                                     -0.181596
# ...                                         ...
# 11227                                 -0.250571
# 11228                                  1.348868
# 11229                                 -0.877616
# 11230                                 -1.290875
# 11231                                  0.268984
#
#        Texture_Cytoplasm_Mito_Sum.Variance_256.3  \
# 0                                       0.132669
# 1                                       0.197211
# 2                                      -0.025754
# 3                                      -0.502716
# 4                                      -0.224879
# ...                                          ...
# 11227                                   0.125689
# 11228                                   0.729634
# 11229                                  -0.876408
# 11230                                  -1.002629
# 11231                                   0.413694
#
#        Area.Size.Shape_Cytoplasm_VOLUME  Area.Size.Shape_Cytoplasm_EXTENT  \
# 0                             -0.063515                         -0.965185
# 1                             -0.039729                         -0.529325
# 2                             -0.088707                         -0.101508
# 3                             -0.156492                         -0.131695
# 4                             -0.120579                          0.584169
# ...                                 ...                               ...
# 11227                         -0.655757                         -0.227980
# 11228                          1.294135                          2.139031
# 11229                         -0.308250                          1.433118
# 11230                         -1.154379                          0.088987
# 11231                         -0.493806                          0.896927
#
#        Area.Size.Shape_Cytoplasm_EULER.NUMBER     Treatment  Pathway  \
# 0                                   -0.394215  Mirdametinib   MEK1/2
# 1                                   -0.810092  Mirdametinib   MEK1/2
# 2                                   -0.061513  Mirdametinib   MEK1/2
# 3                                   -0.103101  Mirdametinib   MEK1/2
# 4                                   -0.851680  Mirdametinib   MEK1/2
# ...                                       ...           ...      ...
# 11227                                0.588797    Trametinib   MEK1/2
# 11228                                1.241738    Trametinib   MEK1/2
# 11229                                1.241738    Trametinib   MEK1/2
# 11230                                1.335016    Trametinib   MEK1/2
# 11231                                1.335016    Trametinib   MEK1/2
#
#               Function           Class  Therapeutic Categories
# 0      Inhibits MEK1/2  Small Molecule      Kinase Inhibitor
# 1      Inhibits MEK1/2  Small Molecule      Kinase Inhibitor
# 2      Inhibits MEK1/2  Small Molecule      Kinase Inhibitor
# 3      Inhibits MEK1/2  Small Molecule      Kinase Inhibitor
# 4      Inhibits MEK1/2  Small Molecule      Kinase Inhibitor
# ...                ...             ...                     ...
# 11227  Inhibits MEK1/2  Small Molecule       Kinase Inhibitor
# 11228  Inhibits MEK1/2  Small Molecule       Kinase Inhibitor
# 11229  Inhibits MEK1/2  Small Molecule       Kinase Inhibitor
# 11230  Inhibits MEK1/2  Small Molecule       Kinase Inhibitor
# 11231  Inhibits MEK1/2  Small Molecule       Kinase Inhibitor
#
# [11232 rows x 327 columns]
