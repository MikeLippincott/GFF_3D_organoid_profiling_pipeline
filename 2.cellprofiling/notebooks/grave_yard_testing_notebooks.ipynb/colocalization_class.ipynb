# %%
import itertools
import pathlib
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.ndimage
import scipy.signal
import skimage
import skimage.io as io
import skimage.morphology
import skimage.segmentation
from centrosome.cpmorphology import fixup_scipy_ndimage_result as fix
from scipy.linalg import lstsq

sys.path.append("../featurization")
import numpy
from area_size_shape import calulate_surface_area, measure_3D_area_size_shape
from colocalization import calculate_3D_colocalization
from data_writer import organize_featurization_data
from granularity import measure_3D_granularity
from intensity import measure_3D_intensity
from loading_classes import Featurization, ImageSetLoader, ObjectLoader
from neighbors import measure_3D_number_of_neighbors
from texture import measure_3D_texture
from two_object_loading_classes import (
    ColocalizationFeaturization,
    ColocalizationTwoObject_Loader,
)

# %%
channel_mapping = {
    "nuclei": "405",
    "AGP": "488",
    "ER": "555",
    "Mito": "640",
    "BF": "TRANS",
    "nuclei_mask": "nuclei_",
    "cell_mask": "cell_",
    "cytoplasm_mask": "cytoplasm_",
    "organoid_mask": "organoid_",
}

# %%
image_set_path = pathlib.Path("../../data/NF0014/cellprofiler/C4-2/")

# %%
image_set_loader = ImageSetLoader(
    image_set_path=image_set_path,
    spacing=(1, 0.1, 0.1),
    channel_mapping=channel_mapping,
)

# %%
# get all combinations of channels, compartments, and objects
colocalization_channel_pairs = []

for channel1 in image_set_loader.image_names:
    for channel2 in image_set_loader.image_names:
        if channel1 != channel2:
            colocalization_channel_pairs.append((channel1, channel2))

for compartment in image_set_loader.compartments:
    for unique_object in image_set_loader.unique_compartment_objects[compartment][1:2]:
        for channel1, channel2 in colocalization_channel_pairs:
            two_object_loader = ColocalizationTwoObject_Loader(
                image_set_loader=image_set_loader,
                image1=image_set_loader.image_set_dict[channel1],
                label_image1=image_set_loader.image_set_dict[compartment],
                object1=unique_object,
                image2=image_set_loader.image_set_dict[channel2],
                label_image2=image_set_loader.image_set_dict[compartment],
                object2=unique_object,
                compartment=compartment,
            )

            featurizer = ColocalizationFeaturization(
                image_set_loader=image_set_loader,
                two_object_loader=two_object_loader,
            )
            features = featurizer.process_features_for_output()
            organize_featurization_data(
                features=features,
                compartment=compartment,
                channel=f"{channel1}-{channel2}",
                label_index=unique_object,
                output=True,
                output_path=pathlib.Path(
                    f"../profiles_features/{image_set_loader.image_set_name}_{compartment}_{channel1}_{channel2}_{unique_object}.parquet"
                ),
                image_set_name=image_set_loader.image_set_name,
                return_df=False,
            )
# Out:
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cell_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for cytoplasm_mask 4 and 4
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for nuclei_mask 8 and 8
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:356: RuntimeWarning: invalid value encountered in divide
#   C2 = scipy.ndimage.sum(si_thresh_c) / numpy.array(tot_si_thr_c)
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2
# /home/lippincm/Documents/GFF_3D_organoid_profiling_pipeline/2.cellprofiling/notebooks/../featurization/colocalization.py:123: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   costReg, _ = scipy.stats.pearsonr(fi[combt], si[combt])
# INFO:root:Calculated Colocalization features for organoid_mask 2 and 2

# %%
pd.read_parquet("../profiles_features/C4-2_cell_mask_AGP_ER_4.parquet")
# Out:
#   image_set  object_index  \
# 0      C4-2             4
#
#    cell_mask_AGP-ER_colocalization_Mean.Correlation.coeff_nosubfeature  \
# 0                                           0.757233
#
#    cell_mask_AGP-ER_colocalization_Median.Correlation.coeff_nosubfeature  \
# 0                                           0.757233
#
#    cell_mask_AGP-ER_colocalization_Min.Correlation.coeff_nosubfeature  \
# 0                                           0.757233
#
#    cell_mask_AGP-ER_colocalization_Max.Correlation.coeff_nosubfeature  \
# 0                                           0.757233
#
#    cell_mask_AGP-ER_colocalization_Mean.Manders.coeff.M1_nosubfeature  \
# 0                                                1.0
#
#    cell_mask_AGP-ER_colocalization_Median.Manders.coeff.M1_nosubfeature  \
# 0                                                1.0
#
#    cell_mask_AGP-ER_colocalization_Min.Manders.coeff.M1_nosubfeature  \
# 0                                                1.0
#
#    cell_mask_AGP-ER_colocalization_Max.Manders.coeff.M1_nosubfeature  ...  \
# 0                                                1.0                  ...
#
#    cell_mask_AGP-ER_colocalization_Min.K2_nosubfeature  \
# 0                                           0.918534
#
#    cell_mask_AGP-ER_colocalization_Max.K2_nosubfeature  \
# 0                                           0.918534
#
#    cell_mask_AGP-ER_colocalization_Mean.Manders.Coeff.costes.M1_nosubfeature  \
# 0                                                0.0
#
#    cell_mask_AGP-ER_colocalization_Median.Manders.Coeff.costes.M1_nosubfeature  \
# 0                                                0.0
#
#    cell_mask_AGP-ER_colocalization_Min.Manders.Coeff.costes.M1_nosubfeature  \
# 0                                                0.0
#
#    cell_mask_AGP-ER_colocalization_Max.Manders.Coeff.costes.M1_nosubfeature  \
# 0                                                0.0
#
#    cell_mask_AGP-ER_colocalization_Mean.Manders.Coeff.costes.M2_nosubfeature  \
# 0                                                NaN
#
#    cell_mask_AGP-ER_colocalization_Median.Manders.Coeff.costes.M2_nosubfeature  \
# 0                                                NaN
#
#    cell_mask_AGP-ER_colocalization_Min.Manders.Coeff.costes.M2_nosubfeature  \
# 0                                                NaN
#
#    cell_mask_AGP-ER_colocalization_Max.Manders.Coeff.costes..M2_nosubfeature
# 0                                                NaN
#
# [1 rows x 34 columns]
