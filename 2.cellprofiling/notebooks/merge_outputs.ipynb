# %%
import pathlib

import numpy as np
import pandas as pd

# %%
path_to_output_files = pathlib.Path("../profiles_features").resolve()
# get all files in the directory
files = path_to_output_files.glob("*")
files = [x for x in files if x.is_file()]
# files = files[:10]

# %%
df = pd.DataFrame(columns=["filename"], data=[x.stem for x in files])
df[["well_fov", "channel", "compartment", "mask", "object"]] = df["filename"].str.split(
    "_", expand=True
)
df.drop(columns=["mask"], inplace=True)
# group the data by well_fov, object
df.groupby(["well_fov", "object"]).agg(lambda x: x.tolist()).reset_index()
# Out:
#     well_fov object                                           filename  \
# 0       C4-2    100  [C4-2_nuclei_cell_mask_100, C4-2_AGP_cell_mask...
# 1       C4-2    102  [C4-2_nuclei_cell_mask_102, C4-2_AGP_cytoplasm...
# 2       C4-2    105  [C4-2_AGP_cytoplasm_mask_105, C4-2_BF_cell_mas...
# 3       C4-2    107  [C4-2_AGP_cell_mask_107, C4-2_BF_cell_mask_107...
# 4       C4-2    110  [C4-2_AGP_cytoplasm_mask_110, C4-2_BF_cell_mas...
# ..       ...    ...                                                ...
# 99      C4-2      9  [C4-2_AGP_cytoplasm_mask_9, C4-2_Mito_cytoplas...
# 100     C4-2     90  [C4-2_nuclei_cytoplasm_mask_90, C4-2_BF_cell_m...
# 101     C4-2     93  [C4-2_BF_cell_mask_93, C4-2_AGP_cytoplasm_mask...
# 102     C4-2     95  [C4-2_nuclei_cytoplasm_mask_95, C4-2_nuclei_ce...
# 103     C4-2     98  [C4-2_nuclei_cell_mask_98, C4-2_BF_cell_mask_9...
#
#                                                channel  \
# 0         [nuclei, AGP, nuclei, ER, ER, Mito, AGP, BF]
# 1         [nuclei, AGP, nuclei, AGP, ER, ER, BF, Mito]
# 2         [AGP, BF, nuclei, AGP, ER, ER, Mito, nuclei]
# 3         [AGP, BF, AGP, ER, Mito, nuclei, nuclei, ER]
# 4         [AGP, BF, nuclei, AGP, ER, Mito, nuclei, ER]
# ..                                                 ...
# 99   [AGP, Mito, AGP, BF, ER, ER, nuclei, Mito, nuc...
# 100       [nuclei, BF, ER, ER, nuclei, AGP, AGP, Mito]
# 101       [BF, AGP, Mito, nuclei, AGP, ER, nuclei, ER]
# 102       [nuclei, nuclei, AGP, ER, BF, AGP, Mito, ER]
# 103       [nuclei, BF, nuclei, ER, ER, Mito, AGP, AGP]
#
#                                            compartment
# 0    [cell, cell, cytoplasm, cell, cytoplasm, cell,...
# 1    [cell, cytoplasm, cytoplasm, cell, cytoplasm, ...
# 2    [cytoplasm, cell, cytoplasm, cell, cytoplasm, ...
# 3    [cell, cell, cytoplasm, cell, cell, cytoplasm,...
# 4    [cytoplasm, cell, cell, cell, cell, cell, cyto...
# ..                                                 ...
# 99   [cytoplasm, cytoplasm, cell, cell, cell, cytop...
# 100  [cytoplasm, cell, cytoplasm, cell, cell, cytop...
# 101  [cell, cytoplasm, cell, cell, cell, cell, cyto...
# 102  [cytoplasm, cell, cell, cytoplasm, cell, cytop...
# 103  [cell, cell, cytoplasm, cytoplasm, cell, cell,...
#
# [104 rows x 5 columns]
