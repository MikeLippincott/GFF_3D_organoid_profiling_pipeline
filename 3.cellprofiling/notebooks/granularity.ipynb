# %%
import argparse
import os
import pathlib
import sys
import time

import psutil

sys.path.append("../featurization_utils")
import multiprocessing
import os
from functools import partial
from itertools import product
from multiprocessing import Pool
from typing import Dict

import cucim
import cupy as cp
import numpy
import numpy as np
import pandas as pd
import psutil
import scipy
import skimage
from granularity_utils import measure_3D_granularity

# from granularity import measure_3D_granularity
from loading_classes import ImageSetLoader, ObjectLoader
from resource_profiling_util import get_mem_and_time_profiling

try:
    cfg = get_ipython().config
    in_notebook = True
except NameError:
    in_notebook = False
if in_notebook:
    from tqdm.notebook import tqdm
else:
    from tqdm import tqdm

# %%
def process_combination(
    args: tuple[str, str],
    image_set_loader: ImageSetLoader,
    output_parent_path: pathlib.Path,
):
    """
    Process a single combination of compartment and channel.

    Parameters
    ----------
    args : tuple
        Args that contain the compartment and channel.
        Ordered as (compartment, channel).
        Yes, order matters here.
        channel : str
            The channel name.
        compartment : str
            The compartment name.
    image_set_loader : Class ImageSetLoader
        This contains the image information needed to retreive the objects.
    output_parent_path : pathlib.Path
        The parent path to save the output files to.
        This is used to create the output directory if it doesn't exist.
    Returns
    -------
    str
        A string indicating the compartment and channel that was processed.
    """
    compartment, channel = args
    object_loader = ObjectLoader(
        image_set_loader.image_set_dict[channel],
        image_set_loader.image_set_dict[compartment],
        channel,
        compartment,
    )
    object_measurements = measure_3D_granularity(
        object_loader=object_loader,
        radius=10,  # radius of the sphere to use for granularity measurement
        granular_spectrum_length=16,  # usually 16 but 2 is used for testing for now
        subsample_size=0.25,  # subsample to 25% of the image to reduce computation time
        image_name=channel,
    )
    final_df = pd.DataFrame(object_measurements)
    # get the mean of each value in the array
    # melt the dataframe to wide format
    final_df = final_df.pivot_table(
        index=["object_id"], columns=["feature"], values=["value"]
    )
    final_df.columns = final_df.columns.droplevel()
    final_df = final_df.reset_index()
    # prepend compartment and channel to column names
    for col in final_df.columns:
        if col == "object_id":
            continue
        else:
            final_df.rename(
                columns={col: f"Granularity_{compartment}_{channel}_{col}"},
                inplace=True,
            )
    final_df.insert(0, "image_set", image_set_loader.image_set_name)
    output_file = pathlib.Path(
        output_parent_path / f"Granularity_{compartment}_{channel}_features.parquet"
    )
    output_file.parent.mkdir(parents=True, exist_ok=True)
    final_df.to_parquet(output_file)

    return f"Processed {compartment} - {channel}"

# %%
if not in_notebook:
    argparser = argparse.ArgumentParser()
    argparser.add_argument(
        "--well_fov",
        type=str,
        default="None",
        help="Well and field of view to process, e.g. 'A01_1'",
    )

    argparser.add_argument(
        "--patient",
        type=str,
        help="Patient ID, e.g. 'NF0014'",
    )

    args = argparser.parse_args()
    well_fov = args.well_fov
    patient = args.patient
    if well_fov == "None":
        raise ValueError(
            "Please provide a well and field of view to process, e.g. 'A01_1'"
        )

else:
    well_fov = "C4-2"
    patient = "NF0014"

image_set_path = pathlib.Path(f"../../data/{patient}/cellprofiler/{well_fov}/")
output_parent_path = pathlib.Path(
    f"../../data/{patient}/extracted_features/{well_fov}/"
)
output_parent_path.mkdir(parents=True, exist_ok=True)

# %%
channel_mapping = {
    "DNA": "405",
    "AGP": "488",
    "ER": "555",
    "Mito": "640",
    "BF": "TRANS",
    "Nuclei": "nuclei_",
    "Cell": "cell_",
    "Cytoplasm": "cytoplasm_",
    "Organoid": "organoid_",
}

# %%
start_time = time.time()
# get starting memory (cpu)
start_mem = psutil.Process(os.getpid()).memory_info().rss / 1024**2

# %%
image_set_loader = ImageSetLoader(
    image_set_path=image_set_path,
    anisotropy_spacing=(1, 0.1, 0.1),
    channel_mapping=channel_mapping,
)

# %%
# Generate all combinations of compartments and channels
combinations = list(
    product(image_set_loader.compartments, image_set_loader.image_names)
)
cores = multiprocessing.cpu_count()
print(f"Using {cores} cores for processing.")
# Use multiprocessing to process combinations in parallel
with multiprocessing.Pool(processes=cores) as pool:
    results = list(
        tqdm(
            pool.imap(
                partial(
                    process_combination,
                    image_set_loader=image_set_loader,
                    output_parent_path=output_parent_path,
                ),
                combinations,
            ),
            desc="Processing combinations",
        )
    )

print("Processing complete.")
# Out:
# Using 24 cores for processing.
# Processing combinations: 0it [00:02, ?it/s]
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-16:
# Traceback (most recent call last):
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-22:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py", line 114, in worker
#     task = get()
#            ^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 387, in get
#     res = self._reader.recv_bytes()
#           ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/queues.py", line 386, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/connection.py", line 437, in _recv_bytes
#     return self._recv(size)
#            ^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/lippincm/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 9
#       8 with multiprocessing.Pool(processes=cores) as pool:
# ----> 9     results = list(
#      10         tqdm(
#      11             pool.imap(
#      12                 partial(
#      13                     process_combination,
#      14                     image_set_loader=image_set_loader,
#      15                     output_parent_path=output_parent_path,
#      16                 ),
#      17                 combinations,
#      18             ),
#      19             desc="Processing combinations",
#      20         )
#      21     )
#      23 print("Processing complete.")
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     249 it = super().__iter__()
# --> 250 for obj in it:
#     251     # return super(tqdm...) will not catch exception
#     252     yield obj
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     354 if timeout is None:
# --> 355     waiter.acquire()
#     356     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[7], line 8
#       6 print(f"Using {cores} cores for processing.")
#       7 # Use multiprocessing to process combinations in parallel
# ----> 8 with multiprocessing.Pool(processes=cores) as pool:
#       9     results = list(
#      10         tqdm(
#      11             pool.imap(
#    (...)
#      20         )
#      21     )
#      23 print("Processing complete.")
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:739, in Pool.__exit__(self, exc_type, exc_val, exc_tb)
#     738 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 739     self.terminate()
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:657, in Pool.terminate(self)
#     655 util.debug('terminating pool')
#     656 self._state = TERMINATE
# --> 657 self._terminate()
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/util.py:227, in Finalize.__call__(self, wr, _finalizer_registry, sub_debug, getpid)
#     224 else:
#     225     sub_debug('finalizer calling %s with args %s and kwargs %s',
#     226               self._callback, self._args, self._kwargs)
# --> 227     res = self._callback(*self._args, **self._kwargs)
#     228 self._weakref = self._callback = self._args = \
#     229                 self._kwargs = self._key = None
#     230 return res
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:695, in Pool._terminate_pool(cls, taskqueue, inqueue, outqueue, pool, change_notifier, worker_handler, task_handler, result_handler, cache)
#     692 task_handler._state = TERMINATE
#     694 util.debug('helping task handler/workers to finish')
# --> 695 cls._help_stuff_finish(inqueue, task_handler, len(pool))
#     697 if (not result_handler.is_alive()) and (len(cache) != 0):
#     698     raise AssertionError(
#     699         "Cannot have cache with result_handler not alive")
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/pool.py:677, in Pool._help_stuff_finish(inqueue, task_handler, size)
#     675 inqueue._rlock.acquire()
#     676 while task_handler.is_alive() and inqueue._reader.poll():
# --> 677     inqueue._reader.recv()
#     678     time.sleep(0)
#
# File ~/miniforge3/envs/GFF_featurization/lib/python3.12/multiprocessing/connection.py:251, in _ConnectionBase.recv(self)
#     249 self._check_readable()
#     250 buf = self._recv_bytes()
# --> 251 return _ForkingPickler.loads(buf.getbuffer())
#
# UnpicklingError: could not find MARK
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
end_mem = psutil.Process(os.getpid()).memory_info().rss / 1024**2
end_time = time.time()
get_mem_and_time_profiling(
    start_mem=start_mem,
    end_mem=end_mem,
    start_time=start_time,
    end_time=end_time,
    feature_type="Colocalization",
    well_fov=well_fov,
    patient_id=patient,
    CPU_GPU="CPU",
)
